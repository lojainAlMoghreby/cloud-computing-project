# %% [markdown]
# # ***Real-Time Sentiment Analysis***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install firebase-admin
# !pip install dash dash-bootstrap-components firebase-admin
# Out:
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.11/dist-packages (6.8.0)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (0.14.3)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.169.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.19.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.24.2)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.20.2)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.7.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2025.4.26)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)
# Collecting dash
#   Downloading dash-3.0.4-py3-none-any.whl.metadata (10 kB)
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-2.0.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.11/dist-packages (6.8.0)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (0.14.3)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.169.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.19.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.24.2)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from firebase-admin) (2.20.2)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dash) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)
# Downloading dash-3.0.4-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 75.7 MB/s eta 0:00:00
# Downloading dash_bootstrap_components-2.0.3-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 18.1 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.0 MB/s eta 0:00:00
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 19.2 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: Werkzeug, retrying, Flask, dash, dash-bootstrap-components
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.1
#     Uninstalling Flask-3.1.1:
#       Successfully uninstalled Flask-3.1.1
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 dash-3.0.4 dash-bootstrap-components-2.0.3 retrying-1.3.4

# %% [markdown]
# # 🔥 Batch Deletion Script for Firebase Firestore ("tweet_sentiments" Collection)

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import time

# Initialize Firebase
if not firebase_admin._apps:
    cred = credentials.Certificate("/content/real-time-sentiment-anal-adf49-firebase-adminsdk-fbsvc-6bd22a44f2.json")
    firebase_admin.initialize_app(cred)

db = firestore.client()

# Safe delete with batch limit
def delete_limited_documents(collection_name, limit=100, delay=2):
    docs = db.collection(collection_name).limit(limit).stream()
    count = 0
    for doc in docs:
        db.collection(collection_name).document(doc.id).delete()
        count += 1
        print(f"Deleted: {doc.id}")
        time.sleep(delay)  # slow down to avoid quota spikes
    print(f"Deleted {count} documents (limit {limit})")

# Run this multiple times manually or in a loop if needed
delete_limited_documents("tweet_sentiments")
# Out:
# Deleted: 01J0bTJseHnGWP13XCw1
# Deleted: 01YyeM2bzn1YDeohh9no
# Deleted: 01eTxdS0sPcH3LPjMPrZ
# Deleted: 01uzJxGv99LfWCaEwD8m
# Deleted: 01wxVWtxTbhRWi5200sq
# Deleted: 01xUwOJYjE68Ox28m1hi
# Deleted: 01zNY1xNI6CSn0X76U7x
# Deleted: 02IgdMQJ2Ue8zF5qYd8v
# Deleted: 02bHc8L8GSGQ6vYugR23
# Deleted: 02cn6rOpVqqaHGAEpOS0
# Deleted: 02l5BgbmPf19VkCFyA4S
# Deleted: 02p6oDDuy5Ea14RKtKXY
# Deleted: 039c086a6ccbaad968d04ce99202c5074cb2244250257341aca17d195b1e927a
# Deleted: 03SmhSbvCaNremfW7zqa
# Deleted: 03UOLcnJMz5t29KoFwvN
# Deleted: 03W7JNxstWMrtXBVOSu5
# Deleted: 03a6453221380077d596bd0e06b302eaf2a227af999f2897b9606de4ed63381f
# Deleted: 03f2dd66a618bc1b5f1ae958b8d8636d80629868f276a9fb0eb532e44941feda
# Deleted: 03f3e2bacf836305f2b6889b2e5020109dd4a6d7a5be91d55c7c7446734b48c8
# Deleted: 03f9e664b4dd0199c6c85e391c285ef0fd1a1c7973b14f17d4605acabe603f48
# Deleted: 03fcb4018f5989c90998d3c67a54f166060b157c7b130f61be795e080d7b983b
# Deleted: 03kriv29CtvLFzvt9R6P
# Deleted: 03lTgfOVuyq43zJTbW6X
# Deleted: 04024ef370883b91d24c5e169d68e47cc968d9c365d7d0c56db2653c215c46bb
# Deleted: 04045ea1ed5fe77608881bebcfed32570bb5a4382f4af0eee40a420989cc9592
# Deleted: 040e316a2da6947c1df09d12fc52c1950b9041c467daa7ce9b4fc1fbfc3f3f35
# Deleted: 042012cc5f37be6b5c9d7956ffbc55f09af16bc6a81ae713d8fb39083b18b161
# Deleted: 042f853847761367eaf887ccb45c72990dcc27f765d535bc452803f7b9822431
# Deleted: 04322858627ef317ad1f02c69e57220233bad23ba8089a1f5c0a90275da82d7d
# Deleted: 0436601e51cc77efae5b19c99b5d072423aa1b7281989a80a0357df990e52bfa
# Deleted: 043a41abebe6b1880a1d4f297bd9e65726953dad9490415979e6f4fd28be6db6
# Deleted: 0449453d298aa4920da7241ea6a99d9873a450094417894872414989746dbdd1
# Deleted: 044a5fb25ec8b576f94efb7ac8d2aa18c91bedf425a1b257f02f296e9ec4116d
# Deleted: 04531097ab0fe3ded3677cf0451fdcacdde6effbc7743bd0b7d9849b378be7e0
# Deleted: 045382c23a90cb98511b2bb60a170b640e5342feae0b90c0ac2303c7f091b32f
# Deleted: 04551fa59b3ebfc2e06da50cc6e0f7842d896e1c0f33a7f5693cc0bff4d12f13
# Deleted: 04864360263e2088372565d8040e557e835a855e858723ad2f2723b89e8557e9
# Deleted: 0491c818595aaae4cbe649975883e42fe7fc96441ce10159cf35939d3339db02
# Deleted: 04AP1eHiILkObR0Afkyp
# Deleted: 04Nv4Zz1g2Pepjzd2pLx
# Deleted: 04SEed5GvcQDfm50IYcV
# Deleted: 04a02401f8c330e718d31bf0e37f65a7c4cfcd55463cb983fc8b4bf51f77b257
# Deleted: 04a47d7b8c2b57bdb1cbc8c2a807cd5c7908cb95bea083b98d9814976309c1b4
# Deleted: 04aUC1CONR9r5af2I12O
# Deleted: 04ca277fa612a07ec83698f0b9aaa88ac10907d9370e78dde827e0e104cf754e
# Deleted: 04dRdbttbSPlL2EnDdP0
# Deleted: 04de7cc8f3ce221425474ee3afff7dc4cb70ca879ee754ad593a99a4f866a2e0
# Deleted: 04dqgBfs4ato9jJrGWEX
# Deleted: 04e1de34f60991cbec2ac307a40d6ab4e8a47820901d4d8ae3bcd2c5ada7b2c6
# Deleted: 04eBq0tHXQKzbqOIPg3d
# Deleted: 04f216e96df403ed5df0b40a700f368e3677be6578d41bca10c5ab0466ffc734
# Deleted: 04f3fcfd7d335312604af586ce04b1dea530d0025e7efd58012d09bb2cc325a3
# Deleted: 04fd1420b9dcbd2343bdd0b05f75f557487583465f1b2b507235e466e9d4503c
# Deleted: 04sptl0NqodeJ1PeRHk7
# Deleted: 051f011dbd7d4051cdfed455c4bbfdd532e305cc4626455dd9625fa6015d2174
# Deleted: 05229792a6d593cb060618246c9a08ef325de560811c9bf418608c1cd462fee8
# Deleted: 0528aa91eeb5ca102748c8b18a02dbc08a8b340b11548a1511673f8d8a88e15e
# Deleted: 052XKZ4IpDYovDgzrQ2l
# Deleted: 052d09e324976941bc7658cf22f2a79db2875836b46fc277eba82471ce417d7d
# Deleted: 053676eed5d5633bca3ec63338df51d7524e8984dbe995d930d554fb7be8f2e4
# Deleted: 054yPJgu9MQOouCmbofF
# Deleted: 0556EcdQfAS7UiW2pkgx
# Deleted: 05575d676032631413b1419a677d22971aef0bd65a7c470f3f4f1b741ff6f835
# Deleted: 05597e33399e5295a54a866a02c25aee0ea0b94b02897adf1f7bda639ef1cbcf
# Deleted: 0559ddd3d1bab6e880ea1731c295fd7a668fcd3b4b26cbb12ed1f9f5940b35d1
# Deleted: 055a7ef7565796b13ef7cb49b75c0bdab5811ad4ee28d599f38e732d4cb67a1e
# Deleted: 055c21703449790769185266b90eddca6c7075d161f7e52d170e80eda9cc12b2
# Deleted: 057a29eda3168af3df54f82623d9cbb597e4ffedc91ec9bbdca62e3e05cbd967
# Deleted: 058901cf2779ce7637b906a08ce687ecd6032af69020087bbccdf0566fd3f29e
# Deleted: 059097cded1932d5f42fcb48ec3f964e1b871101f16a28dbbeae294a77672b93
# Deleted: 05914a9cca8b8e4e120395636c002f24fc85354eaeba2ed7f08e97463394ae9c
# Deleted: 0592ec042ca554cf79f0ac333de1fab7102c4a267328dcda249e66d4796b2342
# Deleted: 059c5f6150b5de356f479e03d3fa09c8eb5fc7a828b95eace618d0b3af2d3896
# Deleted: 059e4e16709991038b733375676eb718734e79bbc901faf53a7fa72e4285bbaf
# Deleted: 05A5NTJdNgbcHYEdhMgx
# Deleted: 05DbJ6qDqHK44OIFr0K9
# Deleted: 05Nz50MnbGESxAF5h0Ri
# Deleted: 05TdgDGmXCmONjNXphcC
# Deleted: 05VtQJ6qq6QgY1hCD5is
# Deleted: 05WlIhceb37WUESv2D9F
# Deleted: 05ac38bdfa49b0c899caaeb7ba930ada5015409494ba554f1be0a36f2b0d9612
# Deleted: 05aecbd30f9762f64f3281e7144f9cd8b9445826128db02ea87a3caa0eb327e6
# Deleted: 05c8d2893beb9a37fcd2738894eb2b575fdc50c0bfcbc4e891400bae920d3cbc
# Deleted: 05e1ca0345cd1fa4c324e1c208a649528445782d37cfcc35362715d15b493e55
# Deleted: 05f58c27c7e93dd0d64d2dea4d9a7a57fbdce374a7da4cfb639513377b1fd1a1
# Deleted: 05f6710441b929460ea6f29f337a6a87b172ab3ec6dc7c91237a6b1412265c05
# Deleted: 05jngU8jOUPmCRscwvtC
# Deleted: 05t0vkWRGdDSbfrCeeu8
# Deleted: 05vBhHKIzrx6J7ILPQ53
# Deleted: 05vwnvPtT5gtBa5GgNjf
# Deleted: 06065775cb0d74e0cee85c4e0778bb989d63cb741fd055233b691118e9298dd5
# Deleted: 062b67571c94dee97b10227327dced545147c6751270f0231939f594a49bd542
# Deleted: 065b2032946e0ee95e8a0cedc3c2f6f9386e006b3d6eedea481a60ab74ca5da6
# Deleted: 066KfQ5PmQovAQYOms0z
# Deleted: 066e343caedd7ec75fb9460cac3e850caa4769147cda95ba988bc2f0f5072915
# Deleted: 0677036496126edd8ad75ffe3fe3d46c097525f1e51a03d584aebf410ace4954
# Deleted: 067af77edfb5f26813c8e91593343699d527da229ba3fa0985881fed0766992d
# Deleted: 06830085aa180f5d410c1ec507cba56bf46e9df62e229d6c47b99cae9737f536
# Deleted: 069a239bc0ce46297b86a68a778bb20994ec1630d0a01d7b1eaa191f989d91f5
# Deleted: 06KYC62DekLvXTDwVCfL
# Deleted 100 documents (limit 100)

# %% [markdown]
# # 💬 Real-Time Tweet Sentiment Analysis with PySpark, HuggingFace Transformers, and Firebase
# This Part performs real-time sentiment analysis on tweets using the following workflow:
# 1. Loads a CSV dataset of tweets using PySpark for distributed processing.
# 2. Cleans and preprocesses the tweet text with a custom UDF.
# 3. Applies a HuggingFace Transformers sentiment analysis model to classify each tweet.
# 4. Saves the results (original text, cleaned text, sentiment label, confidence score) to Firebase Firestore.
# 5. Optionally, saves the output locally as a CSV for offline use or reporting.

# %%
from pyspark.sql import SparkSession
import pandas as pd
import re
from transformers import pipeline
from pyspark.sql.functions import col, udf
from pyspark.sql.types import StringType
import firebase_admin
from firebase_admin import credentials, firestore

# ✅ 1. Initialize Spark session
spark = SparkSession.builder.appName("RealTimeTweetSentiment").getOrCreate()

# ✅ 2. Load tweet dataset
df_spark = spark.read.csv("/content/Tweets.csv", header=True)

# ✅ 3. Define cleaning function and register UDF
def clean_tweet(text):
    text = re.sub(r"http\S+", "", text or "")
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    return text.lower().strip()

clean_udf = udf(clean_tweet, StringType())
df_cleaned = df_spark.withColumn("cleaned_text", clean_udf(col("text")))

# ✅ 4. Filter out empty cleaned_text rows
df_cleaned = df_cleaned.filter((col("cleaned_text").isNotNull()) & (col("cleaned_text") != ""))

# ✅ 5. Convert to Pandas DataFrame
df_pandas = df_cleaned.select("text", "cleaned_text").toPandas()

# ✅ 6. Limit to the first 14641 tweets
df_pandas = df_pandas.head(14641)

# ✅ 7. Load HuggingFace sentiment pipeline
sentiment_model = pipeline("sentiment-analysis")

# ✅ 8. Run sentiment prediction in batch
results = sentiment_model(df_pandas["cleaned_text"].tolist(), batch_size=32, truncation=True)

# ✅ 9. Add results to DataFrame
df_pandas["sentiment"] = [r["label"] for r in results]
df_pandas["confidence"] = [r["score"] for r in results]

# ✅ 10. Initialize Firebase only once
if not firebase_admin._apps:
    cred = credentials.Certificate("/content/real-time-sentiment-anal-adf49-firebase-adminsdk-fbsvc-6bd22a44f2.json")
    firebase_admin.initialize_app(cred)

db = firestore.client()

# ✅ 11. Push each tweet to Firestore
for i, row in df_pandas.iterrows():
    db.collection("tweet_sentiments").add({
        "text": row["text"],
        "cleaned_text": row["cleaned_text"],
        "sentiment": row["sentiment"],
        "confidence": float(row["confidence"]),
        "timestamp": firestore.SERVER_TIMESTAMP
    })
    print(f"✅ Uploaded tweet {i+1}/{len(df_pandas)}")

# ✅ 12. Optional: Save locally
df_pandas.to_csv("/content/sentiment_results_14641.csv", index=False)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0
# Streaming output truncated to the last 5000 lines.
# ✅ Uploaded tweet 9633/14632
# ✅ Uploaded tweet 9634/14632
# ✅ Uploaded tweet 9635/14632
# ✅ Uploaded tweet 9636/14632
# ✅ Uploaded tweet 9637/14632
# ✅ Uploaded tweet 9638/14632
# ✅ Uploaded tweet 9639/14632
# ✅ Uploaded tweet 9640/14632
# ✅ Uploaded tweet 9641/14632
# ✅ Uploaded tweet 9642/14632
# ✅ Uploaded tweet 9643/14632
# ✅ Uploaded tweet 9644/14632
# ✅ Uploaded tweet 9645/14632
# ✅ Uploaded tweet 9646/14632
# ✅ Uploaded tweet 9647/14632
# ✅ Uploaded tweet 9648/14632
# ✅ Uploaded tweet 9649/14632
# ✅ Uploaded tweet 9650/14632
# ✅ Uploaded tweet 9651/14632
# ✅ Uploaded tweet 9652/14632
# ✅ Uploaded tweet 9653/14632
# ✅ Uploaded tweet 9654/14632
# ✅ Uploaded tweet 9655/14632
# ✅ Uploaded tweet 9656/14632
# ✅ Uploaded tweet 9657/14632
# ✅ Uploaded tweet 9658/14632
# ✅ Uploaded tweet 9659/14632
# ✅ Uploaded tweet 9660/14632
# ✅ Uploaded tweet 9661/14632
# ✅ Uploaded tweet 9662/14632
# ✅ Uploaded tweet 9663/14632
# ✅ Uploaded tweet 9664/14632
# ✅ Uploaded tweet 9665/14632
# ✅ Uploaded tweet 9666/14632
# ✅ Uploaded tweet 9667/14632
# ✅ Uploaded tweet 9668/14632
# ✅ Uploaded tweet 9669/14632
# ✅ Uploaded tweet 9670/14632
# ✅ Uploaded tweet 9671/14632
# ✅ Uploaded tweet 9672/14632
# ✅ Uploaded tweet 9673/14632
# ✅ Uploaded tweet 9674/14632
# ✅ Uploaded tweet 9675/14632
# ✅ Uploaded tweet 9676/14632
# ✅ Uploaded tweet 9677/14632
# ✅ Uploaded tweet 9678/14632
# ✅ Uploaded tweet 9679/14632
# ✅ Uploaded tweet 9680/14632
# ✅ Uploaded tweet 9681/14632
# ✅ Uploaded tweet 9682/14632
# ✅ Uploaded tweet 9683/14632
# ✅ Uploaded tweet 9684/14632
# ✅ Uploaded tweet 9685/14632
# ✅ Uploaded tweet 9686/14632
# ✅ Uploaded tweet 9687/14632
# ✅ Uploaded tweet 9688/14632
# ✅ Uploaded tweet 9689/14632
# ✅ Uploaded tweet 9690/14632
# ✅ Uploaded tweet 9691/14632
# ✅ Uploaded tweet 9692/14632
# ✅ Uploaded tweet 9693/14632
# ✅ Uploaded tweet 9694/14632
# ✅ Uploaded tweet 9695/14632
# ✅ Uploaded tweet 9696/14632
# ✅ Uploaded tweet 9697/14632
# ✅ Uploaded tweet 9698/14632
# ✅ Uploaded tweet 9699/14632
# ✅ Uploaded tweet 9700/14632
# ✅ Uploaded tweet 9701/14632
# ✅ Uploaded tweet 9702/14632
# ✅ Uploaded tweet 9703/14632
# ✅ Uploaded tweet 9704/14632
# ✅ Uploaded tweet 9705/14632
# ✅ Uploaded tweet 9706/14632
# ✅ Uploaded tweet 9707/14632
# ✅ Uploaded tweet 9708/14632
# ✅ Uploaded tweet 9709/14632
# ✅ Uploaded tweet 9710/14632
# ✅ Uploaded tweet 9711/14632
# ✅ Uploaded tweet 9712/14632
# ✅ Uploaded tweet 9713/14632
# ✅ Uploaded tweet 9714/14632
# ✅ Uploaded tweet 9715/14632
# ✅ Uploaded tweet 9716/14632
# ✅ Uploaded tweet 9717/14632
# ✅ Uploaded tweet 9718/14632
# ✅ Uploaded tweet 9719/14632
# ✅ Uploaded tweet 9720/14632
# ✅ Uploaded tweet 9721/14632
# ✅ Uploaded tweet 9722/14632
# ✅ Uploaded tweet 9723/14632
# ✅ Uploaded tweet 9724/14632
# ✅ Uploaded tweet 9725/14632
# ✅ Uploaded tweet 9726/14632
# ✅ Uploaded tweet 9727/14632
# ✅ Uploaded tweet 9728/14632
# ✅ Uploaded tweet 9729/14632
# ✅ Uploaded tweet 9730/14632
# ✅ Uploaded tweet 9731/14632
# ✅ Uploaded tweet 9732/14632
# ✅ Uploaded tweet 9733/14632
# ✅ Uploaded tweet 9734/14632
# ✅ Uploaded tweet 9735/14632
# ✅ Uploaded tweet 9736/14632
# ✅ Uploaded tweet 9737/14632
# ✅ Uploaded tweet 9738/14632
# ✅ Uploaded tweet 9739/14632
# ✅ Uploaded tweet 9740/14632
# ✅ Uploaded tweet 9741/14632
# ✅ Uploaded tweet 9742/14632
# ✅ Uploaded tweet 9743/14632
# ✅ Uploaded tweet 9744/14632
# ✅ Uploaded tweet 9745/14632
# ✅ Uploaded tweet 9746/14632
# ✅ Uploaded tweet 9747/14632
# ✅ Uploaded tweet 9748/14632
# ✅ Uploaded tweet 9749/14632
# ✅ Uploaded tweet 9750/14632
# ✅ Uploaded tweet 9751/14632
# ✅ Uploaded tweet 9752/14632
# ✅ Uploaded tweet 9753/14632
# ✅ Uploaded tweet 9754/14632
# ✅ Uploaded tweet 9755/14632
# ✅ Uploaded tweet 9756/14632
# ✅ Uploaded tweet 9757/14632
# ✅ Uploaded tweet 9758/14632
# ✅ Uploaded tweet 9759/14632
# ✅ Uploaded tweet 9760/14632
# ✅ Uploaded tweet 9761/14632
# ✅ Uploaded tweet 9762/14632
# ✅ Uploaded tweet 9763/14632
# ✅ Uploaded tweet 9764/14632
# ✅ Uploaded tweet 9765/14632
# ✅ Uploaded tweet 9766/14632
# ✅ Uploaded tweet 9767/14632
# ✅ Uploaded tweet 9768/14632
# ✅ Uploaded tweet 9769/14632
# ✅ Uploaded tweet 9770/14632
# ✅ Uploaded tweet 9771/14632
# ✅ Uploaded tweet 9772/14632
# ✅ Uploaded tweet 9773/14632
# ✅ Uploaded tweet 9774/14632
# ✅ Uploaded tweet 9775/14632
# ✅ Uploaded tweet 9776/14632
# ✅ Uploaded tweet 9777/14632
# ✅ Uploaded tweet 9778/14632
# ✅ Uploaded tweet 9779/14632
# ✅ Uploaded tweet 9780/14632
# ✅ Uploaded tweet 9781/14632
# ✅ Uploaded tweet 9782/14632
# ✅ Uploaded tweet 9783/14632
# ✅ Uploaded tweet 9784/14632
# ✅ Uploaded tweet 9785/14632
# ✅ Uploaded tweet 9786/14632
# ✅ Uploaded tweet 9787/14632
# ✅ Uploaded tweet 9788/14632
# ✅ Uploaded tweet 9789/14632
# ✅ Uploaded tweet 9790/14632
# ✅ Uploaded tweet 9791/14632
# ✅ Uploaded tweet 9792/14632
# ✅ Uploaded tweet 9793/14632
# ✅ Uploaded tweet 9794/14632
# ✅ Uploaded tweet 9795/14632
# ✅ Uploaded tweet 9796/14632
# ✅ Uploaded tweet 9797/14632
# ✅ Uploaded tweet 9798/14632
# ✅ Uploaded tweet 9799/14632
# ✅ Uploaded tweet 9800/14632
# ✅ Uploaded tweet 9801/14632
# ✅ Uploaded tweet 9802/14632
# ✅ Uploaded tweet 9803/14632
# ✅ Uploaded tweet 9804/14632
# ✅ Uploaded tweet 9805/14632
# ✅ Uploaded tweet 9806/14632
# ✅ Uploaded tweet 9807/14632
# ✅ Uploaded tweet 9808/14632
# ✅ Uploaded tweet 9809/14632
# ✅ Uploaded tweet 9810/14632
# ✅ Uploaded tweet 9811/14632
# ✅ Uploaded tweet 9812/14632
# ✅ Uploaded tweet 9813/14632
# ✅ Uploaded tweet 9814/14632
# ✅ Uploaded tweet 9815/14632
# ✅ Uploaded tweet 9816/14632
# ✅ Uploaded tweet 9817/14632
# ✅ Uploaded tweet 9818/14632
# ✅ Uploaded tweet 9819/14632
# ✅ Uploaded tweet 9820/14632
# ✅ Uploaded tweet 9821/14632
# ✅ Uploaded tweet 9822/14632
# ✅ Uploaded tweet 9823/14632
# ✅ Uploaded tweet 9824/14632
# ✅ Uploaded tweet 9825/14632
# ✅ Uploaded tweet 9826/14632
# ✅ Uploaded tweet 9827/14632
# ✅ Uploaded tweet 9828/14632
# ✅ Uploaded tweet 9829/14632
# ✅ Uploaded tweet 9830/14632
# ✅ Uploaded tweet 9831/14632
# ✅ Uploaded tweet 9832/14632
# ✅ Uploaded tweet 9833/14632
# ✅ Uploaded tweet 9834/14632
# ✅ Uploaded tweet 9835/14632
# ✅ Uploaded tweet 9836/14632
# ✅ Uploaded tweet 9837/14632
# ✅ Uploaded tweet 9838/14632
# ✅ Uploaded tweet 9839/14632
# ✅ Uploaded tweet 9840/14632
# ✅ Uploaded tweet 9841/14632
# ✅ Uploaded tweet 9842/14632
# ✅ Uploaded tweet 9843/14632
# ✅ Uploaded tweet 9844/14632
# ✅ Uploaded tweet 9845/14632
# ✅ Uploaded tweet 9846/14632
# ✅ Uploaded tweet 9847/14632
# ✅ Uploaded tweet 9848/14632
# ✅ Uploaded tweet 9849/14632
# ✅ Uploaded tweet 9850/14632
# ✅ Uploaded tweet 9851/14632
# ✅ Uploaded tweet 9852/14632
# ✅ Uploaded tweet 9853/14632
# ✅ Uploaded tweet 9854/14632
# ✅ Uploaded tweet 9855/14632
# ✅ Uploaded tweet 9856/14632
# ✅ Uploaded tweet 9857/14632
# ✅ Uploaded tweet 9858/14632
# ✅ Uploaded tweet 9859/14632
# ✅ Uploaded tweet 9860/14632
# ✅ Uploaded tweet 9861/14632
# ✅ Uploaded tweet 9862/14632
# ✅ Uploaded tweet 9863/14632
# ✅ Uploaded tweet 9864/14632
# ✅ Uploaded tweet 9865/14632
# ✅ Uploaded tweet 9866/14632
# ✅ Uploaded tweet 9867/14632
# ✅ Uploaded tweet 9868/14632
# ✅ Uploaded tweet 9869/14632
# ✅ Uploaded tweet 9870/14632
# ✅ Uploaded tweet 9871/14632
# ✅ Uploaded tweet 9872/14632
# ✅ Uploaded tweet 9873/14632
# ✅ Uploaded tweet 9874/14632
# ✅ Uploaded tweet 9875/14632
# ✅ Uploaded tweet 9876/14632
# ✅ Uploaded tweet 9877/14632
# ✅ Uploaded tweet 9878/14632
# ✅ Uploaded tweet 9879/14632
# ✅ Uploaded tweet 9880/14632
# ✅ Uploaded tweet 9881/14632
# ✅ Uploaded tweet 9882/14632
# ✅ Uploaded tweet 9883/14632
# ✅ Uploaded tweet 9884/14632
# ✅ Uploaded tweet 9885/14632
# ✅ Uploaded tweet 9886/14632
# ✅ Uploaded tweet 9887/14632
# ✅ Uploaded tweet 9888/14632
# ✅ Uploaded tweet 9889/14632
# ✅ Uploaded tweet 9890/14632
# ✅ Uploaded tweet 9891/14632
# ✅ Uploaded tweet 9892/14632
# ✅ Uploaded tweet 9893/14632
# ✅ Uploaded tweet 9894/14632
# ✅ Uploaded tweet 9895/14632
# ✅ Uploaded tweet 9896/14632
# ✅ Uploaded tweet 9897/14632
# ✅ Uploaded tweet 9898/14632
# ✅ Uploaded tweet 9899/14632
# ✅ Uploaded tweet 9900/14632
# ✅ Uploaded tweet 9901/14632
# ✅ Uploaded tweet 9902/14632
# ✅ Uploaded tweet 9903/14632
# ✅ Uploaded tweet 9904/14632
# ✅ Uploaded tweet 9905/14632
# ✅ Uploaded tweet 9906/14632
# ✅ Uploaded tweet 9907/14632
# ✅ Uploaded tweet 9908/14632
# ✅ Uploaded tweet 9909/14632
# ✅ Uploaded tweet 9910/14632
# ✅ Uploaded tweet 9911/14632
# ✅ Uploaded tweet 9912/14632
# ✅ Uploaded tweet 9913/14632
# ✅ Uploaded tweet 9914/14632
# ✅ Uploaded tweet 9915/14632
# ✅ Uploaded tweet 9916/14632
# ✅ Uploaded tweet 9917/14632
# ✅ Uploaded tweet 9918/14632
# ✅ Uploaded tweet 9919/14632
# ✅ Uploaded tweet 9920/14632
# ✅ Uploaded tweet 9921/14632
# ✅ Uploaded tweet 9922/14632
# ✅ Uploaded tweet 9923/14632
# ✅ Uploaded tweet 9924/14632
# ✅ Uploaded tweet 9925/14632
# ✅ Uploaded tweet 9926/14632
# ✅ Uploaded tweet 9927/14632
# ✅ Uploaded tweet 9928/14632
# ✅ Uploaded tweet 9929/14632
# ✅ Uploaded tweet 9930/14632
# ✅ Uploaded tweet 9931/14632
# ✅ Uploaded tweet 9932/14632
# ✅ Uploaded tweet 9933/14632
# ✅ Uploaded tweet 9934/14632
# ✅ Uploaded tweet 9935/14632
# ✅ Uploaded tweet 9936/14632
# ✅ Uploaded tweet 9937/14632
# ✅ Uploaded tweet 9938/14632
# ✅ Uploaded tweet 9939/14632
# ✅ Uploaded tweet 9940/14632
# ✅ Uploaded tweet 9941/14632
# ✅ Uploaded tweet 9942/14632
# ✅ Uploaded tweet 9943/14632
# ✅ Uploaded tweet 9944/14632
# ✅ Uploaded tweet 9945/14632
# ✅ Uploaded tweet 9946/14632
# ✅ Uploaded tweet 9947/14632
# ✅ Uploaded tweet 9948/14632
# ✅ Uploaded tweet 9949/14632
# ✅ Uploaded tweet 9950/14632
# ✅ Uploaded tweet 9951/14632
# ✅ Uploaded tweet 9952/14632
# ✅ Uploaded tweet 9953/14632
# ✅ Uploaded tweet 9954/14632
# ✅ Uploaded tweet 9955/14632
# ✅ Uploaded tweet 9956/14632
# ✅ Uploaded tweet 9957/14632
# ✅ Uploaded tweet 9958/14632
# ✅ Uploaded tweet 9959/14632
# ✅ Uploaded tweet 9960/14632
# ✅ Uploaded tweet 9961/14632
# ✅ Uploaded tweet 9962/14632
# ✅ Uploaded tweet 9963/14632
# ✅ Uploaded tweet 9964/14632
# ✅ Uploaded tweet 9965/14632
# ✅ Uploaded tweet 9966/14632
# ✅ Uploaded tweet 9967/14632
# ✅ Uploaded tweet 9968/14632
# ✅ Uploaded tweet 9969/14632
# ✅ Uploaded tweet 9970/14632
# ✅ Uploaded tweet 9971/14632
# ✅ Uploaded tweet 9972/14632
# ✅ Uploaded tweet 9973/14632
# ✅ Uploaded tweet 9974/14632
# ✅ Uploaded tweet 9975/14632
# ✅ Uploaded tweet 9976/14632
# ✅ Uploaded tweet 9977/14632
# ✅ Uploaded tweet 9978/14632
# ✅ Uploaded tweet 9979/14632
# ✅ Uploaded tweet 9980/14632
# ✅ Uploaded tweet 9981/14632
# ✅ Uploaded tweet 9982/14632
# ✅ Uploaded tweet 9983/14632
# ✅ Uploaded tweet 9984/14632
# ✅ Uploaded tweet 9985/14632
# ✅ Uploaded tweet 9986/14632
# ✅ Uploaded tweet 9987/14632
# ✅ Uploaded tweet 9988/14632
# ✅ Uploaded tweet 9989/14632
# ✅ Uploaded tweet 9990/14632
# ✅ Uploaded tweet 9991/14632
# ✅ Uploaded tweet 9992/14632
# ✅ Uploaded tweet 9993/14632
# ✅ Uploaded tweet 9994/14632
# ✅ Uploaded tweet 9995/14632
# ✅ Uploaded tweet 9996/14632
# ✅ Uploaded tweet 9997/14632
# ✅ Uploaded tweet 9998/14632
# ✅ Uploaded tweet 9999/14632
# ✅ Uploaded tweet 10000/14632
# ✅ Uploaded tweet 10001/14632
# ✅ Uploaded tweet 10002/14632
# ✅ Uploaded tweet 10003/14632
# ✅ Uploaded tweet 10004/14632
# ✅ Uploaded tweet 10005/14632
# ✅ Uploaded tweet 10006/14632
# ✅ Uploaded tweet 10007/14632
# ✅ Uploaded tweet 10008/14632
# ✅ Uploaded tweet 10009/14632
# ✅ Uploaded tweet 10010/14632
# ✅ Uploaded tweet 10011/14632
# ✅ Uploaded tweet 10012/14632
# ✅ Uploaded tweet 10013/14632
# ✅ Uploaded tweet 10014/14632
# ✅ Uploaded tweet 10015/14632
# ✅ Uploaded tweet 10016/14632
# ✅ Uploaded tweet 10017/14632
# ✅ Uploaded tweet 10018/14632
# ✅ Uploaded tweet 10019/14632
# ✅ Uploaded tweet 10020/14632
# ✅ Uploaded tweet 10021/14632
# ✅ Uploaded tweet 10022/14632
# ✅ Uploaded tweet 10023/14632
# ✅ Uploaded tweet 10024/14632
# ✅ Uploaded tweet 10025/14632
# ✅ Uploaded tweet 10026/14632
# ✅ Uploaded tweet 10027/14632
# ✅ Uploaded tweet 10028/14632
# ✅ Uploaded tweet 10029/14632
# ✅ Uploaded tweet 10030/14632
# ✅ Uploaded tweet 10031/14632
# ✅ Uploaded tweet 10032/14632
# ✅ Uploaded tweet 10033/14632
# ✅ Uploaded tweet 10034/14632
# ✅ Uploaded tweet 10035/14632
# ✅ Uploaded tweet 10036/14632
# ✅ Uploaded tweet 10037/14632
# ✅ Uploaded tweet 10038/14632
# ✅ Uploaded tweet 10039/14632
# ✅ Uploaded tweet 10040/14632
# ✅ Uploaded tweet 10041/14632
# ✅ Uploaded tweet 10042/14632
# ✅ Uploaded tweet 10043/14632
# ✅ Uploaded tweet 10044/14632
# ✅ Uploaded tweet 10045/14632
# ✅ Uploaded tweet 10046/14632
# ✅ Uploaded tweet 10047/14632
# ✅ Uploaded tweet 10048/14632
# ✅ Uploaded tweet 10049/14632
# ✅ Uploaded tweet 10050/14632
# ✅ Uploaded tweet 10051/14632
# ✅ Uploaded tweet 10052/14632
# ✅ Uploaded tweet 10053/14632
# ✅ Uploaded tweet 10054/14632
# ✅ Uploaded tweet 10055/14632
# ✅ Uploaded tweet 10056/14632
# ✅ Uploaded tweet 10057/14632
# ✅ Uploaded tweet 10058/14632
# ✅ Uploaded tweet 10059/14632
# ✅ Uploaded tweet 10060/14632
# ✅ Uploaded tweet 10061/14632
# ✅ Uploaded tweet 10062/14632
# ✅ Uploaded tweet 10063/14632
# ✅ Uploaded tweet 10064/14632
# ✅ Uploaded tweet 10065/14632
# ✅ Uploaded tweet 10066/14632
# ✅ Uploaded tweet 10067/14632
# ✅ Uploaded tweet 10068/14632
# ✅ Uploaded tweet 10069/14632
# ✅ Uploaded tweet 10070/14632
# ✅ Uploaded tweet 10071/14632
# ✅ Uploaded tweet 10072/14632
# ✅ Uploaded tweet 10073/14632
# ✅ Uploaded tweet 10074/14632
# ✅ Uploaded tweet 10075/14632
# ✅ Uploaded tweet 10076/14632
# ✅ Uploaded tweet 10077/14632
# ✅ Uploaded tweet 10078/14632
# ✅ Uploaded tweet 10079/14632
# ✅ Uploaded tweet 10080/14632
# ✅ Uploaded tweet 10081/14632
# ✅ Uploaded tweet 10082/14632
# ✅ Uploaded tweet 10083/14632
# ✅ Uploaded tweet 10084/14632
# ✅ Uploaded tweet 10085/14632
# ✅ Uploaded tweet 10086/14632
# ✅ Uploaded tweet 10087/14632
# ✅ Uploaded tweet 10088/14632
# ✅ Uploaded tweet 10089/14632
# ✅ Uploaded tweet 10090/14632
# ✅ Uploaded tweet 10091/14632
# ✅ Uploaded tweet 10092/14632
# ✅ Uploaded tweet 10093/14632
# ✅ Uploaded tweet 10094/14632
# ✅ Uploaded tweet 10095/14632
# ✅ Uploaded tweet 10096/14632
# ✅ Uploaded tweet 10097/14632
# ✅ Uploaded tweet 10098/14632
# ✅ Uploaded tweet 10099/14632
# ✅ Uploaded tweet 10100/14632
# ✅ Uploaded tweet 10101/14632
# ✅ Uploaded tweet 10102/14632
# ✅ Uploaded tweet 10103/14632
# ✅ Uploaded tweet 10104/14632
# ✅ Uploaded tweet 10105/14632
# ✅ Uploaded tweet 10106/14632
# ✅ Uploaded tweet 10107/14632
# ✅ Uploaded tweet 10108/14632
# ✅ Uploaded tweet 10109/14632
# ✅ Uploaded tweet 10110/14632
# ✅ Uploaded tweet 10111/14632
# ✅ Uploaded tweet 10112/14632
# ✅ Uploaded tweet 10113/14632
# ✅ Uploaded tweet 10114/14632
# ✅ Uploaded tweet 10115/14632
# ✅ Uploaded tweet 10116/14632
# ✅ Uploaded tweet 10117/14632
# ✅ Uploaded tweet 10118/14632
# ✅ Uploaded tweet 10119/14632
# ✅ Uploaded tweet 10120/14632
# ✅ Uploaded tweet 10121/14632
# ✅ Uploaded tweet 10122/14632
# ✅ Uploaded tweet 10123/14632
# ✅ Uploaded tweet 10124/14632
# ✅ Uploaded tweet 10125/14632
# ✅ Uploaded tweet 10126/14632
# ✅ Uploaded tweet 10127/14632
# ✅ Uploaded tweet 10128/14632
# ✅ Uploaded tweet 10129/14632
# ✅ Uploaded tweet 10130/14632
# ✅ Uploaded tweet 10131/14632
# ✅ Uploaded tweet 10132/14632
# ✅ Uploaded tweet 10133/14632
# ✅ Uploaded tweet 10134/14632
# ✅ Uploaded tweet 10135/14632
# ✅ Uploaded tweet 10136/14632
# ✅ Uploaded tweet 10137/14632
# ✅ Uploaded tweet 10138/14632
# ✅ Uploaded tweet 10139/14632
# ✅ Uploaded tweet 10140/14632
# ✅ Uploaded tweet 10141/14632
# ✅ Uploaded tweet 10142/14632
# ✅ Uploaded tweet 10143/14632
# ✅ Uploaded tweet 10144/14632
# ✅ Uploaded tweet 10145/14632
# ✅ Uploaded tweet 10146/14632
# ✅ Uploaded tweet 10147/14632
# ✅ Uploaded tweet 10148/14632
# ✅ Uploaded tweet 10149/14632
# ✅ Uploaded tweet 10150/14632
# ✅ Uploaded tweet 10151/14632
# ✅ Uploaded tweet 10152/14632
# ✅ Uploaded tweet 10153/14632
# ✅ Uploaded tweet 10154/14632
# ✅ Uploaded tweet 10155/14632
# ✅ Uploaded tweet 10156/14632
# ✅ Uploaded tweet 10157/14632
# ✅ Uploaded tweet 10158/14632
# ✅ Uploaded tweet 10159/14632
# ✅ Uploaded tweet 10160/14632
# ✅ Uploaded tweet 10161/14632
# ✅ Uploaded tweet 10162/14632
# ✅ Uploaded tweet 10163/14632
# ✅ Uploaded tweet 10164/14632
# ✅ Uploaded tweet 10165/14632
# ✅ Uploaded tweet 10166/14632
# ✅ Uploaded tweet 10167/14632
# ✅ Uploaded tweet 10168/14632
# ✅ Uploaded tweet 10169/14632
# ✅ Uploaded tweet 10170/14632
# ✅ Uploaded tweet 10171/14632
# ✅ Uploaded tweet 10172/14632
# ✅ Uploaded tweet 10173/14632
# ✅ Uploaded tweet 10174/14632
# ✅ Uploaded tweet 10175/14632
# ✅ Uploaded tweet 10176/14632
# ✅ Uploaded tweet 10177/14632
# ✅ Uploaded tweet 10178/14632
# ✅ Uploaded tweet 10179/14632
# ✅ Uploaded tweet 10180/14632
# ✅ Uploaded tweet 10181/14632
# ✅ Uploaded tweet 10182/14632
# ✅ Uploaded tweet 10183/14632
# ✅ Uploaded tweet 10184/14632
# ✅ Uploaded tweet 10185/14632
# ✅ Uploaded tweet 10186/14632
# ✅ Uploaded tweet 10187/14632
# ✅ Uploaded tweet 10188/14632
# ✅ Uploaded tweet 10189/14632
# ✅ Uploaded tweet 10190/14632
# ✅ Uploaded tweet 10191/14632
# ✅ Uploaded tweet 10192/14632
# ✅ Uploaded tweet 10193/14632
# ✅ Uploaded tweet 10194/14632
# ✅ Uploaded tweet 10195/14632
# ✅ Uploaded tweet 10196/14632
# ✅ Uploaded tweet 10197/14632
# ✅ Uploaded tweet 10198/14632
# ✅ Uploaded tweet 10199/14632
# ✅ Uploaded tweet 10200/14632
# ✅ Uploaded tweet 10201/14632
# ✅ Uploaded tweet 10202/14632
# ✅ Uploaded tweet 10203/14632
# ✅ Uploaded tweet 10204/14632
# ✅ Uploaded tweet 10205/14632
# ✅ Uploaded tweet 10206/14632
# ✅ Uploaded tweet 10207/14632
# ✅ Uploaded tweet 10208/14632
# ✅ Uploaded tweet 10209/14632
# ✅ Uploaded tweet 10210/14632
# ✅ Uploaded tweet 10211/14632
# ✅ Uploaded tweet 10212/14632
# ✅ Uploaded tweet 10213/14632
# ✅ Uploaded tweet 10214/14632
# ✅ Uploaded tweet 10215/14632
# ✅ Uploaded tweet 10216/14632
# ✅ Uploaded tweet 10217/14632
# ✅ Uploaded tweet 10218/14632
# ✅ Uploaded tweet 10219/14632
# ✅ Uploaded tweet 10220/14632
# ✅ Uploaded tweet 10221/14632
# ✅ Uploaded tweet 10222/14632
# ✅ Uploaded tweet 10223/14632
# ✅ Uploaded tweet 10224/14632
# ✅ Uploaded tweet 10225/14632
# ✅ Uploaded tweet 10226/14632
# ✅ Uploaded tweet 10227/14632
# ✅ Uploaded tweet 10228/14632
# ✅ Uploaded tweet 10229/14632
# ✅ Uploaded tweet 10230/14632
# ✅ Uploaded tweet 10231/14632
# ✅ Uploaded tweet 10232/14632
# ✅ Uploaded tweet 10233/14632
# ✅ Uploaded tweet 10234/14632
# ✅ Uploaded tweet 10235/14632
# ✅ Uploaded tweet 10236/14632
# ✅ Uploaded tweet 10237/14632
# ✅ Uploaded tweet 10238/14632
# ✅ Uploaded tweet 10239/14632
# ✅ Uploaded tweet 10240/14632
# ✅ Uploaded tweet 10241/14632
# ✅ Uploaded tweet 10242/14632
# ✅ Uploaded tweet 10243/14632
# ✅ Uploaded tweet 10244/14632
# ✅ Uploaded tweet 10245/14632
# ✅ Uploaded tweet 10246/14632
# ✅ Uploaded tweet 10247/14632
# ✅ Uploaded tweet 10248/14632
# ✅ Uploaded tweet 10249/14632
# ✅ Uploaded tweet 10250/14632
# ✅ Uploaded tweet 10251/14632
# ✅ Uploaded tweet 10252/14632
# ✅ Uploaded tweet 10253/14632
# ✅ Uploaded tweet 10254/14632
# ✅ Uploaded tweet 10255/14632
# ✅ Uploaded tweet 10256/14632
# ✅ Uploaded tweet 10257/14632
# ✅ Uploaded tweet 10258/14632
# ✅ Uploaded tweet 10259/14632
# ✅ Uploaded tweet 10260/14632
# ✅ Uploaded tweet 10261/14632
# ✅ Uploaded tweet 10262/14632
# ✅ Uploaded tweet 10263/14632
# ✅ Uploaded tweet 10264/14632
# ✅ Uploaded tweet 10265/14632
# ✅ Uploaded tweet 10266/14632
# ✅ Uploaded tweet 10267/14632
# ✅ Uploaded tweet 10268/14632
# ✅ Uploaded tweet 10269/14632
# ✅ Uploaded tweet 10270/14632
# ✅ Uploaded tweet 10271/14632
# ✅ Uploaded tweet 10272/14632
# ✅ Uploaded tweet 10273/14632
# ✅ Uploaded tweet 10274/14632
# ✅ Uploaded tweet 10275/14632
# ✅ Uploaded tweet 10276/14632
# ✅ Uploaded tweet 10277/14632
# ✅ Uploaded tweet 10278/14632
# ✅ Uploaded tweet 10279/14632
# ✅ Uploaded tweet 10280/14632
# ✅ Uploaded tweet 10281/14632
# ✅ Uploaded tweet 10282/14632
# ✅ Uploaded tweet 10283/14632
# ✅ Uploaded tweet 10284/14632
# ✅ Uploaded tweet 10285/14632
# ✅ Uploaded tweet 10286/14632
# ✅ Uploaded tweet 10287/14632
# ✅ Uploaded tweet 10288/14632
# ✅ Uploaded tweet 10289/14632
# ✅ Uploaded tweet 10290/14632
# ✅ Uploaded tweet 10291/14632
# ✅ Uploaded tweet 10292/14632
# ✅ Uploaded tweet 10293/14632
# ✅ Uploaded tweet 10294/14632
# ✅ Uploaded tweet 10295/14632
# ✅ Uploaded tweet 10296/14632
# ✅ Uploaded tweet 10297/14632
# ✅ Uploaded tweet 10298/14632
# ✅ Uploaded tweet 10299/14632
# ✅ Uploaded tweet 10300/14632
# ✅ Uploaded tweet 10301/14632
# ✅ Uploaded tweet 10302/14632
# ✅ Uploaded tweet 10303/14632
# ✅ Uploaded tweet 10304/14632
# ✅ Uploaded tweet 10305/14632
# ✅ Uploaded tweet 10306/14632
# ✅ Uploaded tweet 10307/14632
# ✅ Uploaded tweet 10308/14632
# ✅ Uploaded tweet 10309/14632
# ✅ Uploaded tweet 10310/14632
# ✅ Uploaded tweet 10311/14632
# ✅ Uploaded tweet 10312/14632
# ✅ Uploaded tweet 10313/14632
# ✅ Uploaded tweet 10314/14632
# ✅ Uploaded tweet 10315/14632
# ✅ Uploaded tweet 10316/14632
# ✅ Uploaded tweet 10317/14632
# ✅ Uploaded tweet 10318/14632
# ✅ Uploaded tweet 10319/14632
# ✅ Uploaded tweet 10320/14632
# ✅ Uploaded tweet 10321/14632
# ✅ Uploaded tweet 10322/14632
# ✅ Uploaded tweet 10323/14632
# ✅ Uploaded tweet 10324/14632
# ✅ Uploaded tweet 10325/14632
# ✅ Uploaded tweet 10326/14632
# ✅ Uploaded tweet 10327/14632
# ✅ Uploaded tweet 10328/14632
# ✅ Uploaded tweet 10329/14632
# ✅ Uploaded tweet 10330/14632
# ✅ Uploaded tweet 10331/14632
# ✅ Uploaded tweet 10332/14632
# ✅ Uploaded tweet 10333/14632
# ✅ Uploaded tweet 10334/14632
# ✅ Uploaded tweet 10335/14632
# ✅ Uploaded tweet 10336/14632
# ✅ Uploaded tweet 10337/14632
# ✅ Uploaded tweet 10338/14632
# ✅ Uploaded tweet 10339/14632
# ✅ Uploaded tweet 10340/14632
# ✅ Uploaded tweet 10341/14632
# ✅ Uploaded tweet 10342/14632
# ✅ Uploaded tweet 10343/14632
# ✅ Uploaded tweet 10344/14632
# ✅ Uploaded tweet 10345/14632
# ✅ Uploaded tweet 10346/14632
# ✅ Uploaded tweet 10347/14632
# ✅ Uploaded tweet 10348/14632
# ✅ Uploaded tweet 10349/14632
# ✅ Uploaded tweet 10350/14632
# ✅ Uploaded tweet 10351/14632
# ✅ Uploaded tweet 10352/14632
# ✅ Uploaded tweet 10353/14632
# ✅ Uploaded tweet 10354/14632
# ✅ Uploaded tweet 10355/14632
# ✅ Uploaded tweet 10356/14632
# ✅ Uploaded tweet 10357/14632
# ✅ Uploaded tweet 10358/14632
# ✅ Uploaded tweet 10359/14632
# ✅ Uploaded tweet 10360/14632
# ✅ Uploaded tweet 10361/14632
# ✅ Uploaded tweet 10362/14632
# ✅ Uploaded tweet 10363/14632
# ✅ Uploaded tweet 10364/14632
# ✅ Uploaded tweet 10365/14632
# ✅ Uploaded tweet 10366/14632
# ✅ Uploaded tweet 10367/14632
# ✅ Uploaded tweet 10368/14632
# ✅ Uploaded tweet 10369/14632
# ✅ Uploaded tweet 10370/14632
# ✅ Uploaded tweet 10371/14632
# ✅ Uploaded tweet 10372/14632
# ✅ Uploaded tweet 10373/14632
# ✅ Uploaded tweet 10374/14632
# ✅ Uploaded tweet 10375/14632
# ✅ Uploaded tweet 10376/14632
# ✅ Uploaded tweet 10377/14632
# ✅ Uploaded tweet 10378/14632
# ✅ Uploaded tweet 10379/14632
# ✅ Uploaded tweet 10380/14632
# ✅ Uploaded tweet 10381/14632
# ✅ Uploaded tweet 10382/14632
# ✅ Uploaded tweet 10383/14632
# ✅ Uploaded tweet 10384/14632
# ✅ Uploaded tweet 10385/14632
# ✅ Uploaded tweet 10386/14632
# ✅ Uploaded tweet 10387/14632
# ✅ Uploaded tweet 10388/14632
# ✅ Uploaded tweet 10389/14632
# ✅ Uploaded tweet 10390/14632
# ✅ Uploaded tweet 10391/14632
# ✅ Uploaded tweet 10392/14632
# ✅ Uploaded tweet 10393/14632
# ✅ Uploaded tweet 10394/14632
# ✅ Uploaded tweet 10395/14632
# ✅ Uploaded tweet 10396/14632
# ✅ Uploaded tweet 10397/14632
# ✅ Uploaded tweet 10398/14632
# ✅ Uploaded tweet 10399/14632
# ✅ Uploaded tweet 10400/14632
# ✅ Uploaded tweet 10401/14632
# ✅ Uploaded tweet 10402/14632
# ✅ Uploaded tweet 10403/14632
# ✅ Uploaded tweet 10404/14632
# ✅ Uploaded tweet 10405/14632
# ✅ Uploaded tweet 10406/14632
# ✅ Uploaded tweet 10407/14632
# ✅ Uploaded tweet 10408/14632
# ✅ Uploaded tweet 10409/14632
# ✅ Uploaded tweet 10410/14632
# ✅ Uploaded tweet 10411/14632
# ✅ Uploaded tweet 10412/14632
# ✅ Uploaded tweet 10413/14632
# ✅ Uploaded tweet 10414/14632
# ✅ Uploaded tweet 10415/14632
# ✅ Uploaded tweet 10416/14632
# ✅ Uploaded tweet 10417/14632
# ✅ Uploaded tweet 10418/14632
# ✅ Uploaded tweet 10419/14632
# ✅ Uploaded tweet 10420/14632
# ✅ Uploaded tweet 10421/14632
# ✅ Uploaded tweet 10422/14632
# ✅ Uploaded tweet 10423/14632
# ✅ Uploaded tweet 10424/14632
# ✅ Uploaded tweet 10425/14632
# ✅ Uploaded tweet 10426/14632
# ✅ Uploaded tweet 10427/14632
# ✅ Uploaded tweet 10428/14632
# ✅ Uploaded tweet 10429/14632
# ✅ Uploaded tweet 10430/14632
# ✅ Uploaded tweet 10431/14632
# ✅ Uploaded tweet 10432/14632
# ✅ Uploaded tweet 10433/14632
# ✅ Uploaded tweet 10434/14632
# ✅ Uploaded tweet 10435/14632
# ✅ Uploaded tweet 10436/14632
# ✅ Uploaded tweet 10437/14632
# ✅ Uploaded tweet 10438/14632
# ✅ Uploaded tweet 10439/14632
# ✅ Uploaded tweet 10440/14632
# ✅ Uploaded tweet 10441/14632
# ✅ Uploaded tweet 10442/14632
# ✅ Uploaded tweet 10443/14632
# ✅ Uploaded tweet 10444/14632
# ✅ Uploaded tweet 10445/14632
# ✅ Uploaded tweet 10446/14632
# ✅ Uploaded tweet 10447/14632
# ✅ Uploaded tweet 10448/14632
# ✅ Uploaded tweet 10449/14632
# ✅ Uploaded tweet 10450/14632
# ✅ Uploaded tweet 10451/14632
# ✅ Uploaded tweet 10452/14632
# ✅ Uploaded tweet 10453/14632
# ✅ Uploaded tweet 10454/14632
# ✅ Uploaded tweet 10455/14632
# ✅ Uploaded tweet 10456/14632
# ✅ Uploaded tweet 10457/14632
# ✅ Uploaded tweet 10458/14632
# ✅ Uploaded tweet 10459/14632
# ✅ Uploaded tweet 10460/14632
# ✅ Uploaded tweet 10461/14632
# ✅ Uploaded tweet 10462/14632
# ✅ Uploaded tweet 10463/14632
# ✅ Uploaded tweet 10464/14632
# ✅ Uploaded tweet 10465/14632
# ✅ Uploaded tweet 10466/14632
# ✅ Uploaded tweet 10467/14632
# ✅ Uploaded tweet 10468/14632
# ✅ Uploaded tweet 10469/14632
# ✅ Uploaded tweet 10470/14632
# ✅ Uploaded tweet 10471/14632
# ✅ Uploaded tweet 10472/14632
# ✅ Uploaded tweet 10473/14632
# ✅ Uploaded tweet 10474/14632
# ✅ Uploaded tweet 10475/14632
# ✅ Uploaded tweet 10476/14632
# ✅ Uploaded tweet 10477/14632
# ✅ Uploaded tweet 10478/14632
# ✅ Uploaded tweet 10479/14632
# ✅ Uploaded tweet 10480/14632
# ✅ Uploaded tweet 10481/14632
# ✅ Uploaded tweet 10482/14632
# ✅ Uploaded tweet 10483/14632
# ✅ Uploaded tweet 10484/14632
# ✅ Uploaded tweet 10485/14632
# ✅ Uploaded tweet 10486/14632
# ✅ Uploaded tweet 10487/14632
# ✅ Uploaded tweet 10488/14632
# ✅ Uploaded tweet 10489/14632
# ✅ Uploaded tweet 10490/14632
# ✅ Uploaded tweet 10491/14632
# ✅ Uploaded tweet 10492/14632
# ✅ Uploaded tweet 10493/14632
# ✅ Uploaded tweet 10494/14632
# ✅ Uploaded tweet 10495/14632
# ✅ Uploaded tweet 10496/14632
# ✅ Uploaded tweet 10497/14632
# ✅ Uploaded tweet 10498/14632
# ✅ Uploaded tweet 10499/14632
# ✅ Uploaded tweet 10500/14632
# ✅ Uploaded tweet 10501/14632
# ✅ Uploaded tweet 10502/14632
# ✅ Uploaded tweet 10503/14632
# ✅ Uploaded tweet 10504/14632
# ✅ Uploaded tweet 10505/14632
# ✅ Uploaded tweet 10506/14632
# ✅ Uploaded tweet 10507/14632
# ✅ Uploaded tweet 10508/14632
# ✅ Uploaded tweet 10509/14632
# ✅ Uploaded tweet 10510/14632
# ✅ Uploaded tweet 10511/14632
# ✅ Uploaded tweet 10512/14632
# ✅ Uploaded tweet 10513/14632
# ✅ Uploaded tweet 10514/14632
# ✅ Uploaded tweet 10515/14632
# ✅ Uploaded tweet 10516/14632
# ✅ Uploaded tweet 10517/14632
# ✅ Uploaded tweet 10518/14632
# ✅ Uploaded tweet 10519/14632
# ✅ Uploaded tweet 10520/14632
# ✅ Uploaded tweet 10521/14632
# ✅ Uploaded tweet 10522/14632
# ✅ Uploaded tweet 10523/14632
# ✅ Uploaded tweet 10524/14632
# ✅ Uploaded tweet 10525/14632
# ✅ Uploaded tweet 10526/14632
# ✅ Uploaded tweet 10527/14632
# ✅ Uploaded tweet 10528/14632
# ✅ Uploaded tweet 10529/14632
# ✅ Uploaded tweet 10530/14632
# ✅ Uploaded tweet 10531/14632
# ✅ Uploaded tweet 10532/14632
# ✅ Uploaded tweet 10533/14632
# ✅ Uploaded tweet 10534/14632
# ✅ Uploaded tweet 10535/14632
# ✅ Uploaded tweet 10536/14632
# ✅ Uploaded tweet 10537/14632
# ✅ Uploaded tweet 10538/14632
# ✅ Uploaded tweet 10539/14632
# ✅ Uploaded tweet 10540/14632
# ✅ Uploaded tweet 10541/14632
# ✅ Uploaded tweet 10542/14632
# ✅ Uploaded tweet 10543/14632
# ✅ Uploaded tweet 10544/14632
# ✅ Uploaded tweet 10545/14632
# ✅ Uploaded tweet 10546/14632
# ✅ Uploaded tweet 10547/14632
# ✅ Uploaded tweet 10548/14632
# ✅ Uploaded tweet 10549/14632
# ✅ Uploaded tweet 10550/14632
# ✅ Uploaded tweet 10551/14632
# ✅ Uploaded tweet 10552/14632
# ✅ Uploaded tweet 10553/14632
# ✅ Uploaded tweet 10554/14632
# ✅ Uploaded tweet 10555/14632
# ✅ Uploaded tweet 10556/14632
# ✅ Uploaded tweet 10557/14632
# ✅ Uploaded tweet 10558/14632
# ✅ Uploaded tweet 10559/14632
# ✅ Uploaded tweet 10560/14632
# ✅ Uploaded tweet 10561/14632
# ✅ Uploaded tweet 10562/14632
# ✅ Uploaded tweet 10563/14632
# ✅ Uploaded tweet 10564/14632
# ✅ Uploaded tweet 10565/14632
# ✅ Uploaded tweet 10566/14632
# ✅ Uploaded tweet 10567/14632
# ✅ Uploaded tweet 10568/14632
# ✅ Uploaded tweet 10569/14632
# ✅ Uploaded tweet 10570/14632
# ✅ Uploaded tweet 10571/14632
# ✅ Uploaded tweet 10572/14632
# ✅ Uploaded tweet 10573/14632
# ✅ Uploaded tweet 10574/14632
# ✅ Uploaded tweet 10575/14632
# ✅ Uploaded tweet 10576/14632
# ✅ Uploaded tweet 10577/14632
# ✅ Uploaded tweet 10578/14632
# ✅ Uploaded tweet 10579/14632
# ✅ Uploaded tweet 10580/14632
# ✅ Uploaded tweet 10581/14632
# ✅ Uploaded tweet 10582/14632
# ✅ Uploaded tweet 10583/14632
# ✅ Uploaded tweet 10584/14632
# ✅ Uploaded tweet 10585/14632
# ✅ Uploaded tweet 10586/14632
# ✅ Uploaded tweet 10587/14632
# ✅ Uploaded tweet 10588/14632
# ✅ Uploaded tweet 10589/14632
# ✅ Uploaded tweet 10590/14632
# ✅ Uploaded tweet 10591/14632
# ✅ Uploaded tweet 10592/14632
# ✅ Uploaded tweet 10593/14632
# ✅ Uploaded tweet 10594/14632
# ✅ Uploaded tweet 10595/14632
# ✅ Uploaded tweet 10596/14632
# ✅ Uploaded tweet 10597/14632
# ✅ Uploaded tweet 10598/14632
# ✅ Uploaded tweet 10599/14632
# ✅ Uploaded tweet 10600/14632
# ✅ Uploaded tweet 10601/14632
# ✅ Uploaded tweet 10602/14632
# ✅ Uploaded tweet 10603/14632
# ✅ Uploaded tweet 10604/14632
# ✅ Uploaded tweet 10605/14632
# ✅ Uploaded tweet 10606/14632
# ✅ Uploaded tweet 10607/14632
# ✅ Uploaded tweet 10608/14632
# ✅ Uploaded tweet 10609/14632
# ✅ Uploaded tweet 10610/14632
# ✅ Uploaded tweet 10611/14632
# ✅ Uploaded tweet 10612/14632
# ✅ Uploaded tweet 10613/14632
# ✅ Uploaded tweet 10614/14632
# ✅ Uploaded tweet 10615/14632
# ✅ Uploaded tweet 10616/14632
# ✅ Uploaded tweet 10617/14632
# ✅ Uploaded tweet 10618/14632
# ✅ Uploaded tweet 10619/14632
# ✅ Uploaded tweet 10620/14632
# ✅ Uploaded tweet 10621/14632
# ✅ Uploaded tweet 10622/14632
# ✅ Uploaded tweet 10623/14632
# ✅ Uploaded tweet 10624/14632
# ✅ Uploaded tweet 10625/14632
# ✅ Uploaded tweet 10626/14632
# ✅ Uploaded tweet 10627/14632
# ✅ Uploaded tweet 10628/14632
# ✅ Uploaded tweet 10629/14632
# ✅ Uploaded tweet 10630/14632
# ✅ Uploaded tweet 10631/14632
# ✅ Uploaded tweet 10632/14632
# ✅ Uploaded tweet 10633/14632
# ✅ Uploaded tweet 10634/14632
# ✅ Uploaded tweet 10635/14632
# ✅ Uploaded tweet 10636/14632
# ✅ Uploaded tweet 10637/14632
# ✅ Uploaded tweet 10638/14632
# ✅ Uploaded tweet 10639/14632
# ✅ Uploaded tweet 10640/14632
# ✅ Uploaded tweet 10641/14632
# ✅ Uploaded tweet 10642/14632
# ✅ Uploaded tweet 10643/14632
# ✅ Uploaded tweet 10644/14632
# ✅ Uploaded tweet 10645/14632
# ✅ Uploaded tweet 10646/14632
# ✅ Uploaded tweet 10647/14632
# ✅ Uploaded tweet 10648/14632
# ✅ Uploaded tweet 10649/14632
# ✅ Uploaded tweet 10650/14632
# ✅ Uploaded tweet 10651/14632
# ✅ Uploaded tweet 10652/14632
# ✅ Uploaded tweet 10653/14632
# ✅ Uploaded tweet 10654/14632
# ✅ Uploaded tweet 10655/14632
# ✅ Uploaded tweet 10656/14632
# ✅ Uploaded tweet 10657/14632
# ✅ Uploaded tweet 10658/14632
# ✅ Uploaded tweet 10659/14632
# ✅ Uploaded tweet 10660/14632
# ✅ Uploaded tweet 10661/14632
# ✅ Uploaded tweet 10662/14632
# ✅ Uploaded tweet 10663/14632
# ✅ Uploaded tweet 10664/14632
# ✅ Uploaded tweet 10665/14632
# ✅ Uploaded tweet 10666/14632
# ✅ Uploaded tweet 10667/14632
# ✅ Uploaded tweet 10668/14632
# ✅ Uploaded tweet 10669/14632
# ✅ Uploaded tweet 10670/14632
# ✅ Uploaded tweet 10671/14632
# ✅ Uploaded tweet 10672/14632
# ✅ Uploaded tweet 10673/14632
# ✅ Uploaded tweet 10674/14632
# ✅ Uploaded tweet 10675/14632
# ✅ Uploaded tweet 10676/14632
# ✅ Uploaded tweet 10677/14632
# ✅ Uploaded tweet 10678/14632
# ✅ Uploaded tweet 10679/14632
# ✅ Uploaded tweet 10680/14632
# ✅ Uploaded tweet 10681/14632
# ✅ Uploaded tweet 10682/14632
# ✅ Uploaded tweet 10683/14632
# ✅ Uploaded tweet 10684/14632
# ✅ Uploaded tweet 10685/14632
# ✅ Uploaded tweet 10686/14632
# ✅ Uploaded tweet 10687/14632
# ✅ Uploaded tweet 10688/14632
# ✅ Uploaded tweet 10689/14632
# ✅ Uploaded tweet 10690/14632
# ✅ Uploaded tweet 10691/14632
# ✅ Uploaded tweet 10692/14632
# ✅ Uploaded tweet 10693/14632
# ✅ Uploaded tweet 10694/14632
# ✅ Uploaded tweet 10695/14632
# ✅ Uploaded tweet 10696/14632
# ✅ Uploaded tweet 10697/14632
# ✅ Uploaded tweet 10698/14632
# ✅ Uploaded tweet 10699/14632
# ✅ Uploaded tweet 10700/14632
# ✅ Uploaded tweet 10701/14632
# ✅ Uploaded tweet 10702/14632
# ✅ Uploaded tweet 10703/14632
# ✅ Uploaded tweet 10704/14632
# ✅ Uploaded tweet 10705/14632
# ✅ Uploaded tweet 10706/14632
# ✅ Uploaded tweet 10707/14632
# ✅ Uploaded tweet 10708/14632
# ✅ Uploaded tweet 10709/14632
# ✅ Uploaded tweet 10710/14632
# ✅ Uploaded tweet 10711/14632
# ✅ Uploaded tweet 10712/14632
# ✅ Uploaded tweet 10713/14632
# ✅ Uploaded tweet 10714/14632
# ✅ Uploaded tweet 10715/14632
# ✅ Uploaded tweet 10716/14632
# ✅ Uploaded tweet 10717/14632
# ✅ Uploaded tweet 10718/14632
# ✅ Uploaded tweet 10719/14632
# ✅ Uploaded tweet 10720/14632
# ✅ Uploaded tweet 10721/14632
# ✅ Uploaded tweet 10722/14632
# ✅ Uploaded tweet 10723/14632
# ✅ Uploaded tweet 10724/14632
# ✅ Uploaded tweet 10725/14632
# ✅ Uploaded tweet 10726/14632
# ✅ Uploaded tweet 10727/14632
# ✅ Uploaded tweet 10728/14632
# ✅ Uploaded tweet 10729/14632
# ✅ Uploaded tweet 10730/14632
# ✅ Uploaded tweet 10731/14632
# ✅ Uploaded tweet 10732/14632
# ✅ Uploaded tweet 10733/14632
# ✅ Uploaded tweet 10734/14632
# ✅ Uploaded tweet 10735/14632
# ✅ Uploaded tweet 10736/14632
# ✅ Uploaded tweet 10737/14632
# ✅ Uploaded tweet 10738/14632
# ✅ Uploaded tweet 10739/14632
# ✅ Uploaded tweet 10740/14632
# ✅ Uploaded tweet 10741/14632
# ✅ Uploaded tweet 10742/14632
# ✅ Uploaded tweet 10743/14632
# ✅ Uploaded tweet 10744/14632
# ✅ Uploaded tweet 10745/14632
# ✅ Uploaded tweet 10746/14632
# ✅ Uploaded tweet 10747/14632
# ✅ Uploaded tweet 10748/14632
# ✅ Uploaded tweet 10749/14632
# ✅ Uploaded tweet 10750/14632
# ✅ Uploaded tweet 10751/14632
# ✅ Uploaded tweet 10752/14632
# ✅ Uploaded tweet 10753/14632
# ✅ Uploaded tweet 10754/14632
# ✅ Uploaded tweet 10755/14632
# ✅ Uploaded tweet 10756/14632
# ✅ Uploaded tweet 10757/14632
# ✅ Uploaded tweet 10758/14632
# ✅ Uploaded tweet 10759/14632
# ✅ Uploaded tweet 10760/14632
# ✅ Uploaded tweet 10761/14632
# ✅ Uploaded tweet 10762/14632
# ✅ Uploaded tweet 10763/14632
# ✅ Uploaded tweet 10764/14632
# ✅ Uploaded tweet 10765/14632
# ✅ Uploaded tweet 10766/14632
# ✅ Uploaded tweet 10767/14632
# ✅ Uploaded tweet 10768/14632
# ✅ Uploaded tweet 10769/14632
# ✅ Uploaded tweet 10770/14632
# ✅ Uploaded tweet 10771/14632
# ✅ Uploaded tweet 10772/14632
# ✅ Uploaded tweet 10773/14632
# ✅ Uploaded tweet 10774/14632
# ✅ Uploaded tweet 10775/14632
# ✅ Uploaded tweet 10776/14632
# ✅ Uploaded tweet 10777/14632
# ✅ Uploaded tweet 10778/14632
# ✅ Uploaded tweet 10779/14632
# ✅ Uploaded tweet 10780/14632
# ✅ Uploaded tweet 10781/14632
# ✅ Uploaded tweet 10782/14632
# ✅ Uploaded tweet 10783/14632
# ✅ Uploaded tweet 10784/14632
# ✅ Uploaded tweet 10785/14632
# ✅ Uploaded tweet 10786/14632
# ✅ Uploaded tweet 10787/14632
# ✅ Uploaded tweet 10788/14632
# ✅ Uploaded tweet 10789/14632
# ✅ Uploaded tweet 10790/14632
# ✅ Uploaded tweet 10791/14632
# ✅ Uploaded tweet 10792/14632
# ✅ Uploaded tweet 10793/14632
# ✅ Uploaded tweet 10794/14632
# ✅ Uploaded tweet 10795/14632
# ✅ Uploaded tweet 10796/14632
# ✅ Uploaded tweet 10797/14632
# ✅ Uploaded tweet 10798/14632
# ✅ Uploaded tweet 10799/14632
# ✅ Uploaded tweet 10800/14632
# ✅ Uploaded tweet 10801/14632
# ✅ Uploaded tweet 10802/14632
# ✅ Uploaded tweet 10803/14632
# ✅ Uploaded tweet 10804/14632
# ✅ Uploaded tweet 10805/14632
# ✅ Uploaded tweet 10806/14632
# ✅ Uploaded tweet 10807/14632
# ✅ Uploaded tweet 10808/14632
# ✅ Uploaded tweet 10809/14632
# ✅ Uploaded tweet 10810/14632
# ✅ Uploaded tweet 10811/14632
# ✅ Uploaded tweet 10812/14632
# ✅ Uploaded tweet 10813/14632
# ✅ Uploaded tweet 10814/14632
# ✅ Uploaded tweet 10815/14632
# ✅ Uploaded tweet 10816/14632
# ✅ Uploaded tweet 10817/14632
# ✅ Uploaded tweet 10818/14632
# ✅ Uploaded tweet 10819/14632
# ✅ Uploaded tweet 10820/14632
# ✅ Uploaded tweet 10821/14632
# ✅ Uploaded tweet 10822/14632
# ✅ Uploaded tweet 10823/14632
# ✅ Uploaded tweet 10824/14632
# ✅ Uploaded tweet 10825/14632
# ✅ Uploaded tweet 10826/14632
# ✅ Uploaded tweet 10827/14632
# ✅ Uploaded tweet 10828/14632
# ✅ Uploaded tweet 10829/14632
# ✅ Uploaded tweet 10830/14632
# ✅ Uploaded tweet 10831/14632
# ✅ Uploaded tweet 10832/14632
# ✅ Uploaded tweet 10833/14632
# ✅ Uploaded tweet 10834/14632
# ✅ Uploaded tweet 10835/14632
# ✅ Uploaded tweet 10836/14632
# ✅ Uploaded tweet 10837/14632
# ✅ Uploaded tweet 10838/14632
# ✅ Uploaded tweet 10839/14632
# ✅ Uploaded tweet 10840/14632
# ✅ Uploaded tweet 10841/14632
# ✅ Uploaded tweet 10842/14632
# ✅ Uploaded tweet 10843/14632
# ✅ Uploaded tweet 10844/14632
# ✅ Uploaded tweet 10845/14632
# ✅ Uploaded tweet 10846/14632
# ✅ Uploaded tweet 10847/14632
# ✅ Uploaded tweet 10848/14632
# ✅ Uploaded tweet 10849/14632
# ✅ Uploaded tweet 10850/14632
# ✅ Uploaded tweet 10851/14632
# ✅ Uploaded tweet 10852/14632
# ✅ Uploaded tweet 10853/14632
# ✅ Uploaded tweet 10854/14632
# ✅ Uploaded tweet 10855/14632
# ✅ Uploaded tweet 10856/14632
# ✅ Uploaded tweet 10857/14632
# ✅ Uploaded tweet 10858/14632
# ✅ Uploaded tweet 10859/14632
# ✅ Uploaded tweet 10860/14632
# ✅ Uploaded tweet 10861/14632
# ✅ Uploaded tweet 10862/14632
# ✅ Uploaded tweet 10863/14632
# ✅ Uploaded tweet 10864/14632
# ✅ Uploaded tweet 10865/14632
# ✅ Uploaded tweet 10866/14632
# ✅ Uploaded tweet 10867/14632
# ✅ Uploaded tweet 10868/14632
# ✅ Uploaded tweet 10869/14632
# ✅ Uploaded tweet 10870/14632
# ✅ Uploaded tweet 10871/14632
# ✅ Uploaded tweet 10872/14632
# ✅ Uploaded tweet 10873/14632
# ✅ Uploaded tweet 10874/14632
# ✅ Uploaded tweet 10875/14632
# ✅ Uploaded tweet 10876/14632
# ✅ Uploaded tweet 10877/14632
# ✅ Uploaded tweet 10878/14632
# ✅ Uploaded tweet 10879/14632
# ✅ Uploaded tweet 10880/14632
# ✅ Uploaded tweet 10881/14632
# ✅ Uploaded tweet 10882/14632
# ✅ Uploaded tweet 10883/14632
# ✅ Uploaded tweet 10884/14632
# ✅ Uploaded tweet 10885/14632
# ✅ Uploaded tweet 10886/14632
# ✅ Uploaded tweet 10887/14632
# ✅ Uploaded tweet 10888/14632
# ✅ Uploaded tweet 10889/14632
# ✅ Uploaded tweet 10890/14632
# ✅ Uploaded tweet 10891/14632
# ✅ Uploaded tweet 10892/14632
# ✅ Uploaded tweet 10893/14632
# ✅ Uploaded tweet 10894/14632
# ✅ Uploaded tweet 10895/14632
# ✅ Uploaded tweet 10896/14632
# ✅ Uploaded tweet 10897/14632
# ✅ Uploaded tweet 10898/14632
# ✅ Uploaded tweet 10899/14632
# ✅ Uploaded tweet 10900/14632
# ✅ Uploaded tweet 10901/14632
# ✅ Uploaded tweet 10902/14632
# ✅ Uploaded tweet 10903/14632
# ✅ Uploaded tweet 10904/14632
# ✅ Uploaded tweet 10905/14632
# ✅ Uploaded tweet 10906/14632
# ✅ Uploaded tweet 10907/14632
# ✅ Uploaded tweet 10908/14632
# ✅ Uploaded tweet 10909/14632
# ✅ Uploaded tweet 10910/14632
# ✅ Uploaded tweet 10911/14632
# ✅ Uploaded tweet 10912/14632
# ✅ Uploaded tweet 10913/14632
# ✅ Uploaded tweet 10914/14632
# ✅ Uploaded tweet 10915/14632
# ✅ Uploaded tweet 10916/14632
# ✅ Uploaded tweet 10917/14632
# ✅ Uploaded tweet 10918/14632
# ✅ Uploaded tweet 10919/14632
# ✅ Uploaded tweet 10920/14632
# ✅ Uploaded tweet 10921/14632
# ✅ Uploaded tweet 10922/14632
# ✅ Uploaded tweet 10923/14632
# ✅ Uploaded tweet 10924/14632
# ✅ Uploaded tweet 10925/14632
# ✅ Uploaded tweet 10926/14632
# ✅ Uploaded tweet 10927/14632
# ✅ Uploaded tweet 10928/14632
# ✅ Uploaded tweet 10929/14632
# ✅ Uploaded tweet 10930/14632
# ✅ Uploaded tweet 10931/14632
# ✅ Uploaded tweet 10932/14632
# ✅ Uploaded tweet 10933/14632
# ✅ Uploaded tweet 10934/14632
# ✅ Uploaded tweet 10935/14632
# ✅ Uploaded tweet 10936/14632
# ✅ Uploaded tweet 10937/14632
# ✅ Uploaded tweet 10938/14632
# ✅ Uploaded tweet 10939/14632
# ✅ Uploaded tweet 10940/14632
# ✅ Uploaded tweet 10941/14632
# ✅ Uploaded tweet 10942/14632
# ✅ Uploaded tweet 10943/14632
# ✅ Uploaded tweet 10944/14632
# ✅ Uploaded tweet 10945/14632
# ✅ Uploaded tweet 10946/14632
# ✅ Uploaded tweet 10947/14632
# ✅ Uploaded tweet 10948/14632
# ✅ Uploaded tweet 10949/14632
# ✅ Uploaded tweet 10950/14632
# ✅ Uploaded tweet 10951/14632
# ✅ Uploaded tweet 10952/14632
# ✅ Uploaded tweet 10953/14632
# ✅ Uploaded tweet 10954/14632
# ✅ Uploaded tweet 10955/14632
# ✅ Uploaded tweet 10956/14632
# ✅ Uploaded tweet 10957/14632
# ✅ Uploaded tweet 10958/14632
# ✅ Uploaded tweet 10959/14632
# ✅ Uploaded tweet 10960/14632
# ✅ Uploaded tweet 10961/14632
# ✅ Uploaded tweet 10962/14632
# ✅ Uploaded tweet 10963/14632
# ✅ Uploaded tweet 10964/14632
# ✅ Uploaded tweet 10965/14632
# ✅ Uploaded tweet 10966/14632
# ✅ Uploaded tweet 10967/14632
# ✅ Uploaded tweet 10968/14632
# ✅ Uploaded tweet 10969/14632
# ✅ Uploaded tweet 10970/14632
# ✅ Uploaded tweet 10971/14632
# ✅ Uploaded tweet 10972/14632
# ✅ Uploaded tweet 10973/14632
# ✅ Uploaded tweet 10974/14632
# ✅ Uploaded tweet 10975/14632
# ✅ Uploaded tweet 10976/14632
# ✅ Uploaded tweet 10977/14632
# ✅ Uploaded tweet 10978/14632
# ✅ Uploaded tweet 10979/14632
# ✅ Uploaded tweet 10980/14632
# ✅ Uploaded tweet 10981/14632
# ✅ Uploaded tweet 10982/14632
# ✅ Uploaded tweet 10983/14632
# ✅ Uploaded tweet 10984/14632
# ✅ Uploaded tweet 10985/14632
# ✅ Uploaded tweet 10986/14632
# ✅ Uploaded tweet 10987/14632
# ✅ Uploaded tweet 10988/14632
# ✅ Uploaded tweet 10989/14632
# ✅ Uploaded tweet 10990/14632
# ✅ Uploaded tweet 10991/14632
# ✅ Uploaded tweet 10992/14632
# ✅ Uploaded tweet 10993/14632
# ✅ Uploaded tweet 10994/14632
# ✅ Uploaded tweet 10995/14632
# ✅ Uploaded tweet 10996/14632
# ✅ Uploaded tweet 10997/14632
# ✅ Uploaded tweet 10998/14632
# ✅ Uploaded tweet 10999/14632
# ✅ Uploaded tweet 11000/14632
# ✅ Uploaded tweet 11001/14632
# ✅ Uploaded tweet 11002/14632
# ✅ Uploaded tweet 11003/14632
# ✅ Uploaded tweet 11004/14632
# ✅ Uploaded tweet 11005/14632
# ✅ Uploaded tweet 11006/14632
# ✅ Uploaded tweet 11007/14632
# ✅ Uploaded tweet 11008/14632
# ✅ Uploaded tweet 11009/14632
# ✅ Uploaded tweet 11010/14632
# ✅ Uploaded tweet 11011/14632
# ✅ Uploaded tweet 11012/14632
# ✅ Uploaded tweet 11013/14632
# ✅ Uploaded tweet 11014/14632
# ✅ Uploaded tweet 11015/14632
# ✅ Uploaded tweet 11016/14632
# ✅ Uploaded tweet 11017/14632
# ✅ Uploaded tweet 11018/14632
# ✅ Uploaded tweet 11019/14632
# ✅ Uploaded tweet 11020/14632
# ✅ Uploaded tweet 11021/14632
# ✅ Uploaded tweet 11022/14632
# ✅ Uploaded tweet 11023/14632
# ✅ Uploaded tweet 11024/14632
# ✅ Uploaded tweet 11025/14632
# ✅ Uploaded tweet 11026/14632
# ✅ Uploaded tweet 11027/14632
# ✅ Uploaded tweet 11028/14632
# ✅ Uploaded tweet 11029/14632
# ✅ Uploaded tweet 11030/14632
# ✅ Uploaded tweet 11031/14632
# ✅ Uploaded tweet 11032/14632
# ✅ Uploaded tweet 11033/14632
# ✅ Uploaded tweet 11034/14632
# ✅ Uploaded tweet 11035/14632
# ✅ Uploaded tweet 11036/14632
# ✅ Uploaded tweet 11037/14632
# ✅ Uploaded tweet 11038/14632
# ✅ Uploaded tweet 11039/14632
# ✅ Uploaded tweet 11040/14632
# ✅ Uploaded tweet 11041/14632
# ✅ Uploaded tweet 11042/14632
# ✅ Uploaded tweet 11043/14632
# ✅ Uploaded tweet 11044/14632
# ✅ Uploaded tweet 11045/14632
# ✅ Uploaded tweet 11046/14632
# ✅ Uploaded tweet 11047/14632
# ✅ Uploaded tweet 11048/14632
# ✅ Uploaded tweet 11049/14632
# ✅ Uploaded tweet 11050/14632
# ✅ Uploaded tweet 11051/14632
# ✅ Uploaded tweet 11052/14632
# ✅ Uploaded tweet 11053/14632
# ✅ Uploaded tweet 11054/14632
# ✅ Uploaded tweet 11055/14632
# ✅ Uploaded tweet 11056/14632
# ✅ Uploaded tweet 11057/14632
# ✅ Uploaded tweet 11058/14632
# ✅ Uploaded tweet 11059/14632
# ✅ Uploaded tweet 11060/14632
# ✅ Uploaded tweet 11061/14632
# ✅ Uploaded tweet 11062/14632
# ✅ Uploaded tweet 11063/14632
# ✅ Uploaded tweet 11064/14632
# ✅ Uploaded tweet 11065/14632
# ✅ Uploaded tweet 11066/14632
# ✅ Uploaded tweet 11067/14632
# ✅ Uploaded tweet 11068/14632
# ✅ Uploaded tweet 11069/14632
# ✅ Uploaded tweet 11070/14632
# ✅ Uploaded tweet 11071/14632
# ✅ Uploaded tweet 11072/14632
# ✅ Uploaded tweet 11073/14632
# ✅ Uploaded tweet 11074/14632
# ✅ Uploaded tweet 11075/14632
# ✅ Uploaded tweet 11076/14632
# ✅ Uploaded tweet 11077/14632
# ✅ Uploaded tweet 11078/14632
# ✅ Uploaded tweet 11079/14632
# ✅ Uploaded tweet 11080/14632
# ✅ Uploaded tweet 11081/14632
# ✅ Uploaded tweet 11082/14632
# ✅ Uploaded tweet 11083/14632
# ✅ Uploaded tweet 11084/14632
# ✅ Uploaded tweet 11085/14632
# ✅ Uploaded tweet 11086/14632
# ✅ Uploaded tweet 11087/14632
# ✅ Uploaded tweet 11088/14632
# ✅ Uploaded tweet 11089/14632
# ✅ Uploaded tweet 11090/14632
# ✅ Uploaded tweet 11091/14632
# ✅ Uploaded tweet 11092/14632
# ✅ Uploaded tweet 11093/14632
# ✅ Uploaded tweet 11094/14632
# ✅ Uploaded tweet 11095/14632
# ✅ Uploaded tweet 11096/14632
# ✅ Uploaded tweet 11097/14632
# ✅ Uploaded tweet 11098/14632
# ✅ Uploaded tweet 11099/14632
# ✅ Uploaded tweet 11100/14632
# ✅ Uploaded tweet 11101/14632
# ✅ Uploaded tweet 11102/14632
# ✅ Uploaded tweet 11103/14632
# ✅ Uploaded tweet 11104/14632
# ✅ Uploaded tweet 11105/14632
# ✅ Uploaded tweet 11106/14632
# ✅ Uploaded tweet 11107/14632
# ✅ Uploaded tweet 11108/14632
# ✅ Uploaded tweet 11109/14632
# ✅ Uploaded tweet 11110/14632
# ✅ Uploaded tweet 11111/14632
# ✅ Uploaded tweet 11112/14632
# ✅ Uploaded tweet 11113/14632
# ✅ Uploaded tweet 11114/14632
# ✅ Uploaded tweet 11115/14632
# ✅ Uploaded tweet 11116/14632
# ✅ Uploaded tweet 11117/14632
# ✅ Uploaded tweet 11118/14632
# ✅ Uploaded tweet 11119/14632
# ✅ Uploaded tweet 11120/14632
# ✅ Uploaded tweet 11121/14632
# ✅ Uploaded tweet 11122/14632
# ✅ Uploaded tweet 11123/14632
# ✅ Uploaded tweet 11124/14632
# ✅ Uploaded tweet 11125/14632
# ✅ Uploaded tweet 11126/14632
# ✅ Uploaded tweet 11127/14632
# ✅ Uploaded tweet 11128/14632
# ✅ Uploaded tweet 11129/14632
# ✅ Uploaded tweet 11130/14632
# ✅ Uploaded tweet 11131/14632
# ✅ Uploaded tweet 11132/14632
# ✅ Uploaded tweet 11133/14632
# ✅ Uploaded tweet 11134/14632
# ✅ Uploaded tweet 11135/14632
# ✅ Uploaded tweet 11136/14632
# ✅ Uploaded tweet 11137/14632
# ✅ Uploaded tweet 11138/14632
# ✅ Uploaded tweet 11139/14632
# ✅ Uploaded tweet 11140/14632
# ✅ Uploaded tweet 11141/14632
# ✅ Uploaded tweet 11142/14632
# ✅ Uploaded tweet 11143/14632
# ✅ Uploaded tweet 11144/14632
# ✅ Uploaded tweet 11145/14632
# ✅ Uploaded tweet 11146/14632
# ✅ Uploaded tweet 11147/14632
# ✅ Uploaded tweet 11148/14632
# ✅ Uploaded tweet 11149/14632
# ✅ Uploaded tweet 11150/14632
# ✅ Uploaded tweet 11151/14632
# ✅ Uploaded tweet 11152/14632
# ✅ Uploaded tweet 11153/14632
# ✅ Uploaded tweet 11154/14632
# ✅ Uploaded tweet 11155/14632
# ✅ Uploaded tweet 11156/14632
# ✅ Uploaded tweet 11157/14632
# ✅ Uploaded tweet 11158/14632
# ✅ Uploaded tweet 11159/14632
# ✅ Uploaded tweet 11160/14632
# ✅ Uploaded tweet 11161/14632
# ✅ Uploaded tweet 11162/14632
# ✅ Uploaded tweet 11163/14632
# ✅ Uploaded tweet 11164/14632
# ✅ Uploaded tweet 11165/14632
# ✅ Uploaded tweet 11166/14632
# ✅ Uploaded tweet 11167/14632
# ✅ Uploaded tweet 11168/14632
# ✅ Uploaded tweet 11169/14632
# ✅ Uploaded tweet 11170/14632
# ✅ Uploaded tweet 11171/14632
# ✅ Uploaded tweet 11172/14632
# ✅ Uploaded tweet 11173/14632
# ✅ Uploaded tweet 11174/14632
# ✅ Uploaded tweet 11175/14632
# ✅ Uploaded tweet 11176/14632
# ✅ Uploaded tweet 11177/14632
# ✅ Uploaded tweet 11178/14632
# ✅ Uploaded tweet 11179/14632
# ✅ Uploaded tweet 11180/14632
# ✅ Uploaded tweet 11181/14632
# ✅ Uploaded tweet 11182/14632
# ✅ Uploaded tweet 11183/14632
# ✅ Uploaded tweet 11184/14632
# ✅ Uploaded tweet 11185/14632
# ✅ Uploaded tweet 11186/14632
# ✅ Uploaded tweet 11187/14632
# ✅ Uploaded tweet 11188/14632
# ✅ Uploaded tweet 11189/14632
# ✅ Uploaded tweet 11190/14632
# ✅ Uploaded tweet 11191/14632
# ✅ Uploaded tweet 11192/14632
# ✅ Uploaded tweet 11193/14632
# ✅ Uploaded tweet 11194/14632
# ✅ Uploaded tweet 11195/14632
# ✅ Uploaded tweet 11196/14632
# ✅ Uploaded tweet 11197/14632
# ✅ Uploaded tweet 11198/14632
# ✅ Uploaded tweet 11199/14632
# ✅ Uploaded tweet 11200/14632
# ✅ Uploaded tweet 11201/14632
# ✅ Uploaded tweet 11202/14632
# ✅ Uploaded tweet 11203/14632
# ✅ Uploaded tweet 11204/14632
# ✅ Uploaded tweet 11205/14632
# ✅ Uploaded tweet 11206/14632
# ✅ Uploaded tweet 11207/14632
# ✅ Uploaded tweet 11208/14632
# ✅ Uploaded tweet 11209/14632
# ✅ Uploaded tweet 11210/14632
# ✅ Uploaded tweet 11211/14632
# ✅ Uploaded tweet 11212/14632
# ✅ Uploaded tweet 11213/14632
# ✅ Uploaded tweet 11214/14632
# ✅ Uploaded tweet 11215/14632
# ✅ Uploaded tweet 11216/14632
# ✅ Uploaded tweet 11217/14632
# ✅ Uploaded tweet 11218/14632
# ✅ Uploaded tweet 11219/14632
# ✅ Uploaded tweet 11220/14632
# ✅ Uploaded tweet 11221/14632
# ✅ Uploaded tweet 11222/14632
# ✅ Uploaded tweet 11223/14632
# ✅ Uploaded tweet 11224/14632
# ✅ Uploaded tweet 11225/14632
# ✅ Uploaded tweet 11226/14632
# ✅ Uploaded tweet 11227/14632
# ✅ Uploaded tweet 11228/14632
# ✅ Uploaded tweet 11229/14632
# ✅ Uploaded tweet 11230/14632
# ✅ Uploaded tweet 11231/14632
# ✅ Uploaded tweet 11232/14632
# ✅ Uploaded tweet 11233/14632
# ✅ Uploaded tweet 11234/14632
# ✅ Uploaded tweet 11235/14632
# ✅ Uploaded tweet 11236/14632
# ✅ Uploaded tweet 11237/14632
# ✅ Uploaded tweet 11238/14632
# ✅ Uploaded tweet 11239/14632
# ✅ Uploaded tweet 11240/14632
# ✅ Uploaded tweet 11241/14632
# ✅ Uploaded tweet 11242/14632
# ✅ Uploaded tweet 11243/14632
# ✅ Uploaded tweet 11244/14632
# ✅ Uploaded tweet 11245/14632
# ✅ Uploaded tweet 11246/14632
# ✅ Uploaded tweet 11247/14632
# ✅ Uploaded tweet 11248/14632
# ✅ Uploaded tweet 11249/14632
# ✅ Uploaded tweet 11250/14632
# ✅ Uploaded tweet 11251/14632
# ✅ Uploaded tweet 11252/14632
# ✅ Uploaded tweet 11253/14632
# ✅ Uploaded tweet 11254/14632
# ✅ Uploaded tweet 11255/14632
# ✅ Uploaded tweet 11256/14632
# ✅ Uploaded tweet 11257/14632
# ✅ Uploaded tweet 11258/14632
# ✅ Uploaded tweet 11259/14632
# ✅ Uploaded tweet 11260/14632
# ✅ Uploaded tweet 11261/14632
# ✅ Uploaded tweet 11262/14632
# ✅ Uploaded tweet 11263/14632
# ✅ Uploaded tweet 11264/14632
# ✅ Uploaded tweet 11265/14632
# ✅ Uploaded tweet 11266/14632
# ✅ Uploaded tweet 11267/14632
# ✅ Uploaded tweet 11268/14632
# ✅ Uploaded tweet 11269/14632
# ✅ Uploaded tweet 11270/14632
# ✅ Uploaded tweet 11271/14632
# ✅ Uploaded tweet 11272/14632
# ✅ Uploaded tweet 11273/14632
# ✅ Uploaded tweet 11274/14632
# ✅ Uploaded tweet 11275/14632
# ✅ Uploaded tweet 11276/14632
# ✅ Uploaded tweet 11277/14632
# ✅ Uploaded tweet 11278/14632
# ✅ Uploaded tweet 11279/14632
# ✅ Uploaded tweet 11280/14632
# ✅ Uploaded tweet 11281/14632
# ✅ Uploaded tweet 11282/14632
# ✅ Uploaded tweet 11283/14632
# ✅ Uploaded tweet 11284/14632
# ✅ Uploaded tweet 11285/14632
# ✅ Uploaded tweet 11286/14632
# ...
# ✅ Uploaded tweet 14082/14632
# ✅ Uploaded tweet 14083/14632
# ✅ Uploaded tweet 14084/14632
# ✅ Uploaded tweet 14085/14632
# ✅ Uploaded tweet 14086/14632
# ✅ Uploaded tweet 14087/14632
# ✅ Uploaded tweet 14088/14632
# ✅ Uploaded tweet 14089/14632
# ✅ Uploaded tweet 14090/14632
# ✅ Uploaded tweet 14091/14632
# ✅ Uploaded tweet 14092/14632
# ✅ Uploaded tweet 14093/14632
# ✅ Uploaded tweet 14094/14632
# ✅ Uploaded tweet 14095/14632
# ✅ Uploaded tweet 14096/14632
# ✅ Uploaded tweet 14097/14632
# ✅ Uploaded tweet 14098/14632
# ✅ Uploaded tweet 14099/14632
# ✅ Uploaded tweet 14100/14632
# ✅ Uploaded tweet 14101/14632
# ✅ Uploaded tweet 14102/14632
# ✅ Uploaded tweet 14103/14632
# ✅ Uploaded tweet 14104/14632
# ✅ Uploaded tweet 14105/14632
# ✅ Uploaded tweet 14106/14632
# ✅ Uploaded tweet 14107/14632
# ✅ Uploaded tweet 14108/14632
# ✅ Uploaded tweet 14109/14632
# ✅ Uploaded tweet 14110/14632
# ✅ Uploaded tweet 14111/14632
# ✅ Uploaded tweet 14112/14632
# ✅ Uploaded tweet 14113/14632
# ✅ Uploaded tweet 14114/14632
# ✅ Uploaded tweet 14115/14632
# ✅ Uploaded tweet 14116/14632
# ✅ Uploaded tweet 14117/14632
# ✅ Uploaded tweet 14118/14632
# ✅ Uploaded tweet 14119/14632
# ✅ Uploaded tweet 14120/14632
# ✅ Uploaded tweet 14121/14632
# ✅ Uploaded tweet 14122/14632
# ✅ Uploaded tweet 14123/14632
# ✅ Uploaded tweet 14124/14632
# ✅ Uploaded tweet 14125/14632
# ✅ Uploaded tweet 14126/14632
# ✅ Uploaded tweet 14127/14632
# ✅ Uploaded tweet 14128/14632
# ✅ Uploaded tweet 14129/14632
# ✅ Uploaded tweet 14130/14632
# ✅ Uploaded tweet 14131/14632
# ✅ Uploaded tweet 14132/14632
# ✅ Uploaded tweet 14133/14632
# ✅ Uploaded tweet 14134/14632
# ✅ Uploaded tweet 14135/14632
# ✅ Uploaded tweet 14136/14632
# ✅ Uploaded tweet 14137/14632
# ✅ Uploaded tweet 14138/14632
# ✅ Uploaded tweet 14139/14632
# ✅ Uploaded tweet 14140/14632
# ✅ Uploaded tweet 14141/14632
# ✅ Uploaded tweet 14142/14632
# ✅ Uploaded tweet 14143/14632
# ✅ Uploaded tweet 14144/14632
# ✅ Uploaded tweet 14145/14632
# ✅ Uploaded tweet 14146/14632
# ✅ Uploaded tweet 14147/14632
# ✅ Uploaded tweet 14148/14632
# ✅ Uploaded tweet 14149/14632
# ✅ Uploaded tweet 14150/14632
# ✅ Uploaded tweet 14151/14632
# ✅ Uploaded tweet 14152/14632
# ✅ Uploaded tweet 14153/14632
# ✅ Uploaded tweet 14154/14632
# ✅ Uploaded tweet 14155/14632
# ✅ Uploaded tweet 14156/14632
# ✅ Uploaded tweet 14157/14632
# ✅ Uploaded tweet 14158/14632
# ✅ Uploaded tweet 14159/14632
# ✅ Uploaded tweet 14160/14632
# ✅ Uploaded tweet 14161/14632
# ✅ Uploaded tweet 14162/14632
# ✅ Uploaded tweet 14163/14632
# ✅ Uploaded tweet 14164/14632
# ✅ Uploaded tweet 14165/14632
# ✅ Uploaded tweet 14166/14632
# ✅ Uploaded tweet 14167/14632
# ✅ Uploaded tweet 14168/14632
# ✅ Uploaded tweet 14169/14632
# ✅ Uploaded tweet 14170/14632
# ✅ Uploaded tweet 14171/14632
# ✅ Uploaded tweet 14172/14632
# ✅ Uploaded tweet 14173/14632
# ✅ Uploaded tweet 14174/14632
# ✅ Uploaded tweet 14175/14632
# ✅ Uploaded tweet 14176/14632
# ✅ Uploaded tweet 14177/14632
# ✅ Uploaded tweet 14178/14632
# ✅ Uploaded tweet 14179/14632
# ✅ Uploaded tweet 14180/14632
# ✅ Uploaded tweet 14181/14632
# ✅ Uploaded tweet 14182/14632
# ✅ Uploaded tweet 14183/14632
# ✅ Uploaded tweet 14184/14632
# ✅ Uploaded tweet 14185/14632
# ✅ Uploaded tweet 14186/14632
# ✅ Uploaded tweet 14187/14632
# ✅ Uploaded tweet 14188/14632
# ✅ Uploaded tweet 14189/14632
# ✅ Uploaded tweet 14190/14632
# ✅ Uploaded tweet 14191/14632
# ✅ Uploaded tweet 14192/14632
# ✅ Uploaded tweet 14193/14632
# ✅ Uploaded tweet 14194/14632
# ✅ Uploaded tweet 14195/14632
# ✅ Uploaded tweet 14196/14632
# ✅ Uploaded tweet 14197/14632
# ✅ Uploaded tweet 14198/14632
# ✅ Uploaded tweet 14199/14632
# ✅ Uploaded tweet 14200/14632
# ✅ Uploaded tweet 14201/14632
# ✅ Uploaded tweet 14202/14632
# ✅ Uploaded tweet 14203/14632
# ✅ Uploaded tweet 14204/14632
# ✅ Uploaded tweet 14205/14632
# ✅ Uploaded tweet 14206/14632
# ✅ Uploaded tweet 14207/14632
# ✅ Uploaded tweet 14208/14632
# ✅ Uploaded tweet 14209/14632
# ✅ Uploaded tweet 14210/14632
# ✅ Uploaded tweet 14211/14632
# ✅ Uploaded tweet 14212/14632
# ✅ Uploaded tweet 14213/14632
# ✅ Uploaded tweet 14214/14632
# ✅ Uploaded tweet 14215/14632
# ✅ Uploaded tweet 14216/14632
# ✅ Uploaded tweet 14217/14632
# ✅ Uploaded tweet 14218/14632
# ✅ Uploaded tweet 14219/14632
# ✅ Uploaded tweet 14220/14632
# ✅ Uploaded tweet 14221/14632
# ✅ Uploaded tweet 14222/14632
# ✅ Uploaded tweet 14223/14632
# ✅ Uploaded tweet 14224/14632
# ✅ Uploaded tweet 14225/14632
# ✅ Uploaded tweet 14226/14632
# ✅ Uploaded tweet 14227/14632
# ✅ Uploaded tweet 14228/14632
# ✅ Uploaded tweet 14229/14632
# ✅ Uploaded tweet 14230/14632
# ✅ Uploaded tweet 14231/14632
# ✅ Uploaded tweet 14232/14632
# ✅ Uploaded tweet 14233/14632
# ✅ Uploaded tweet 14234/14632
# ✅ Uploaded tweet 14235/14632
# ✅ Uploaded tweet 14236/14632
# ✅ Uploaded tweet 14237/14632
# ✅ Uploaded tweet 14238/14632
# ✅ Uploaded tweet 14239/14632
# ✅ Uploaded tweet 14240/14632
# ✅ Uploaded tweet 14241/14632
# ✅ Uploaded tweet 14242/14632
# ✅ Uploaded tweet 14243/14632
# ✅ Uploaded tweet 14244/14632
# ✅ Uploaded tweet 14245/14632
# ✅ Uploaded tweet 14246/14632
# ✅ Uploaded tweet 14247/14632
# ✅ Uploaded tweet 14248/14632
# ✅ Uploaded tweet 14249/14632
# ✅ Uploaded tweet 14250/14632
# ✅ Uploaded tweet 14251/14632
# ✅ Uploaded tweet 14252/14632
# ✅ Uploaded tweet 14253/14632
# ✅ Uploaded tweet 14254/14632
# ✅ Uploaded tweet 14255/14632
# ✅ Uploaded tweet 14256/14632
# ✅ Uploaded tweet 14257/14632
# ✅ Uploaded tweet 14258/14632
# ✅ Uploaded tweet 14259/14632
# ✅ Uploaded tweet 14260/14632
# ✅ Uploaded tweet 14261/14632
# ✅ Uploaded tweet 14262/14632
# ✅ Uploaded tweet 14263/14632
# ✅ Uploaded tweet 14264/14632
# ✅ Uploaded tweet 14265/14632
# ✅ Uploaded tweet 14266/14632
# ✅ Uploaded tweet 14267/14632
# ✅ Uploaded tweet 14268/14632
# ✅ Uploaded tweet 14269/14632
# ✅ Uploaded tweet 14270/14632
# ✅ Uploaded tweet 14271/14632
# ✅ Uploaded tweet 14272/14632
# ✅ Uploaded tweet 14273/14632
# ✅ Uploaded tweet 14274/14632
# ✅ Uploaded tweet 14275/14632
# ✅ Uploaded tweet 14276/14632
# ✅ Uploaded tweet 14277/14632
# ✅ Uploaded tweet 14278/14632
# ✅ Uploaded tweet 14279/14632
# ✅ Uploaded tweet 14280/14632
# ✅ Uploaded tweet 14281/14632
# ✅ Uploaded tweet 14282/14632
# ✅ Uploaded tweet 14283/14632
# ✅ Uploaded tweet 14284/14632
# ✅ Uploaded tweet 14285/14632
# ✅ Uploaded tweet 14286/14632
# ✅ Uploaded tweet 14287/14632
# ✅ Uploaded tweet 14288/14632
# ✅ Uploaded tweet 14289/14632
# ✅ Uploaded tweet 14290/14632
# ✅ Uploaded tweet 14291/14632
# ✅ Uploaded tweet 14292/14632
# ✅ Uploaded tweet 14293/14632
# ✅ Uploaded tweet 14294/14632
# ✅ Uploaded tweet 14295/14632
# ✅ Uploaded tweet 14296/14632
# ✅ Uploaded tweet 14297/14632
# ✅ Uploaded tweet 14298/14632
# ✅ Uploaded tweet 14299/14632
# ✅ Uploaded tweet 14300/14632
# ✅ Uploaded tweet 14301/14632
# ✅ Uploaded tweet 14302/14632
# ✅ Uploaded tweet 14303/14632
# ✅ Uploaded tweet 14304/14632
# ✅ Uploaded tweet 14305/14632
# ✅ Uploaded tweet 14306/14632
# ✅ Uploaded tweet 14307/14632
# ✅ Uploaded tweet 14308/14632
# ✅ Uploaded tweet 14309/14632
# ✅ Uploaded tweet 14310/14632
# ✅ Uploaded tweet 14311/14632
# ✅ Uploaded tweet 14312/14632
# ✅ Uploaded tweet 14313/14632
# ✅ Uploaded tweet 14314/14632
# ✅ Uploaded tweet 14315/14632
# ✅ Uploaded tweet 14316/14632
# ✅ Uploaded tweet 14317/14632
# ✅ Uploaded tweet 14318/14632
# ✅ Uploaded tweet 14319/14632
# ✅ Uploaded tweet 14320/14632
# ✅ Uploaded tweet 14321/14632
# ✅ Uploaded tweet 14322/14632
# ✅ Uploaded tweet 14323/14632
# ✅ Uploaded tweet 14324/14632
# ✅ Uploaded tweet 14325/14632
# ✅ Uploaded tweet 14326/14632
# ✅ Uploaded tweet 14327/14632
# ✅ Uploaded tweet 14328/14632
# ✅ Uploaded tweet 14329/14632
# ✅ Uploaded tweet 14330/14632
# ✅ Uploaded tweet 14331/14632
# ✅ Uploaded tweet 14332/14632
# ✅ Uploaded tweet 14333/14632
# ✅ Uploaded tweet 14334/14632
# ✅ Uploaded tweet 14335/14632
# ✅ Uploaded tweet 14336/14632
# ✅ Uploaded tweet 14337/14632
# ✅ Uploaded tweet 14338/14632
# ✅ Uploaded tweet 14339/14632
# ✅ Uploaded tweet 14340/14632
# ✅ Uploaded tweet 14341/14632
# ✅ Uploaded tweet 14342/14632
# ✅ Uploaded tweet 14343/14632
# ✅ Uploaded tweet 14344/14632
# ✅ Uploaded tweet 14345/14632
# ✅ Uploaded tweet 14346/14632
# ✅ Uploaded tweet 14347/14632
# ✅ Uploaded tweet 14348/14632
# ✅ Uploaded tweet 14349/14632
# ✅ Uploaded tweet 14350/14632
# ✅ Uploaded tweet 14351/14632
# ✅ Uploaded tweet 14352/14632
# ✅ Uploaded tweet 14353/14632
# ✅ Uploaded tweet 14354/14632
# ✅ Uploaded tweet 14355/14632
# ✅ Uploaded tweet 14356/14632
# ✅ Uploaded tweet 14357/14632
# ✅ Uploaded tweet 14358/14632
# ✅ Uploaded tweet 14359/14632
# ✅ Uploaded tweet 14360/14632
# ✅ Uploaded tweet 14361/14632
# ✅ Uploaded tweet 14362/14632
# ✅ Uploaded tweet 14363/14632
# ✅ Uploaded tweet 14364/14632
# ✅ Uploaded tweet 14365/14632
# ✅ Uploaded tweet 14366/14632
# ✅ Uploaded tweet 14367/14632
# ✅ Uploaded tweet 14368/14632
# ✅ Uploaded tweet 14369/14632
# ✅ Uploaded tweet 14370/14632
# ✅ Uploaded tweet 14371/14632
# ✅ Uploaded tweet 14372/14632
# ✅ Uploaded tweet 14373/14632
# ✅ Uploaded tweet 14374/14632
# ✅ Uploaded tweet 14375/14632
# ✅ Uploaded tweet 14376/14632
# ✅ Uploaded tweet 14377/14632
# ✅ Uploaded tweet 14378/14632
# ✅ Uploaded tweet 14379/14632
# ✅ Uploaded tweet 14380/14632
# ✅ Uploaded tweet 14381/14632
# ✅ Uploaded tweet 14382/14632
# ✅ Uploaded tweet 14383/14632
# ✅ Uploaded tweet 14384/14632
# ✅ Uploaded tweet 14385/14632
# ✅ Uploaded tweet 14386/14632
# ✅ Uploaded tweet 14387/14632
# ✅ Uploaded tweet 14388/14632
# ✅ Uploaded tweet 14389/14632
# ✅ Uploaded tweet 14390/14632
# ✅ Uploaded tweet 14391/14632
# ✅ Uploaded tweet 14392/14632
# ✅ Uploaded tweet 14393/14632
# ✅ Uploaded tweet 14394/14632
# ✅ Uploaded tweet 14395/14632
# ✅ Uploaded tweet 14396/14632
# ✅ Uploaded tweet 14397/14632
# ✅ Uploaded tweet 14398/14632
# ✅ Uploaded tweet 14399/14632
# ✅ Uploaded tweet 14400/14632
# ✅ Uploaded tweet 14401/14632
# ✅ Uploaded tweet 14402/14632
# ✅ Uploaded tweet 14403/14632
# ✅ Uploaded tweet 14404/14632
# ✅ Uploaded tweet 14405/14632
# ✅ Uploaded tweet 14406/14632
# ✅ Uploaded tweet 14407/14632
# ✅ Uploaded tweet 14408/14632
# ✅ Uploaded tweet 14409/14632
# ✅ Uploaded tweet 14410/14632
# ✅ Uploaded tweet 14411/14632
# ✅ Uploaded tweet 14412/14632
# ✅ Uploaded tweet 14413/14632
# ✅ Uploaded tweet 14414/14632
# ✅ Uploaded tweet 14415/14632
# ✅ Uploaded tweet 14416/14632
# ✅ Uploaded tweet 14417/14632
# ✅ Uploaded tweet 14418/14632
# ✅ Uploaded tweet 14419/14632
# ✅ Uploaded tweet 14420/14632
# ✅ Uploaded tweet 14421/14632
# ✅ Uploaded tweet 14422/14632
# ✅ Uploaded tweet 14423/14632
# ✅ Uploaded tweet 14424/14632
# ✅ Uploaded tweet 14425/14632
# ✅ Uploaded tweet 14426/14632
# ✅ Uploaded tweet 14427/14632
# ✅ Uploaded tweet 14428/14632
# ✅ Uploaded tweet 14429/14632
# ✅ Uploaded tweet 14430/14632
# ✅ Uploaded tweet 14431/14632
# ✅ Uploaded tweet 14432/14632
# ✅ Uploaded tweet 14433/14632
# ✅ Uploaded tweet 14434/14632
# ✅ Uploaded tweet 14435/14632
# ✅ Uploaded tweet 14436/14632
# ✅ Uploaded tweet 14437/14632
# ✅ Uploaded tweet 14438/14632
# ✅ Uploaded tweet 14439/14632
# ✅ Uploaded tweet 14440/14632
# ✅ Uploaded tweet 14441/14632
# ✅ Uploaded tweet 14442/14632
# ✅ Uploaded tweet 14443/14632
# ✅ Uploaded tweet 14444/14632
# ✅ Uploaded tweet 14445/14632
# ✅ Uploaded tweet 14446/14632
# ✅ Uploaded tweet 14447/14632
# ✅ Uploaded tweet 14448/14632
# ✅ Uploaded tweet 14449/14632
# ✅ Uploaded tweet 14450/14632
# ✅ Uploaded tweet 14451/14632
# ✅ Uploaded tweet 14452/14632
# ✅ Uploaded tweet 14453/14632
# ✅ Uploaded tweet 14454/14632
# ✅ Uploaded tweet 14455/14632
# ✅ Uploaded tweet 14456/14632
# ✅ Uploaded tweet 14457/14632
# ✅ Uploaded tweet 14458/14632
# ✅ Uploaded tweet 14459/14632
# ✅ Uploaded tweet 14460/14632
# ✅ Uploaded tweet 14461/14632
# ✅ Uploaded tweet 14462/14632
# ✅ Uploaded tweet 14463/14632
# ✅ Uploaded tweet 14464/14632
# ✅ Uploaded tweet 14465/14632
# ✅ Uploaded tweet 14466/14632
# ✅ Uploaded tweet 14467/14632
# ✅ Uploaded tweet 14468/14632
# ✅ Uploaded tweet 14469/14632
# ✅ Uploaded tweet 14470/14632
# ✅ Uploaded tweet 14471/14632
# ✅ Uploaded tweet 14472/14632
# ✅ Uploaded tweet 14473/14632
# ✅ Uploaded tweet 14474/14632
# ✅ Uploaded tweet 14475/14632
# ✅ Uploaded tweet 14476/14632
# ✅ Uploaded tweet 14477/14632
# ✅ Uploaded tweet 14478/14632
# ✅ Uploaded tweet 14479/14632
# ✅ Uploaded tweet 14480/14632
# ✅ Uploaded tweet 14481/14632
# ✅ Uploaded tweet 14482/14632
# ✅ Uploaded tweet 14483/14632
# ✅ Uploaded tweet 14484/14632
# ✅ Uploaded tweet 14485/14632
# ✅ Uploaded tweet 14486/14632
# ✅ Uploaded tweet 14487/14632
# ✅ Uploaded tweet 14488/14632
# ✅ Uploaded tweet 14489/14632
# ✅ Uploaded tweet 14490/14632
# ✅ Uploaded tweet 14491/14632
# ✅ Uploaded tweet 14492/14632
# ✅ Uploaded tweet 14493/14632
# ✅ Uploaded tweet 14494/14632
# ✅ Uploaded tweet 14495/14632
# ✅ Uploaded tweet 14496/14632
# ✅ Uploaded tweet 14497/14632
# ✅ Uploaded tweet 14498/14632
# ✅ Uploaded tweet 14499/14632
# ✅ Uploaded tweet 14500/14632
# ✅ Uploaded tweet 14501/14632
# ✅ Uploaded tweet 14502/14632
# ✅ Uploaded tweet 14503/14632
# ✅ Uploaded tweet 14504/14632
# ✅ Uploaded tweet 14505/14632
# ✅ Uploaded tweet 14506/14632
# ✅ Uploaded tweet 14507/14632
# ✅ Uploaded tweet 14508/14632
# ✅ Uploaded tweet 14509/14632
# ✅ Uploaded tweet 14510/14632
# ✅ Uploaded tweet 14511/14632
# ✅ Uploaded tweet 14512/14632
# ✅ Uploaded tweet 14513/14632
# ✅ Uploaded tweet 14514/14632
# ✅ Uploaded tweet 14515/14632
# ✅ Uploaded tweet 14516/14632
# ✅ Uploaded tweet 14517/14632
# ✅ Uploaded tweet 14518/14632
# ✅ Uploaded tweet 14519/14632
# ✅ Uploaded tweet 14520/14632
# ✅ Uploaded tweet 14521/14632
# ✅ Uploaded tweet 14522/14632
# ✅ Uploaded tweet 14523/14632
# ✅ Uploaded tweet 14524/14632
# ✅ Uploaded tweet 14525/14632
# ✅ Uploaded tweet 14526/14632
# ✅ Uploaded tweet 14527/14632
# ✅ Uploaded tweet 14528/14632
# ✅ Uploaded tweet 14529/14632
# ✅ Uploaded tweet 14530/14632
# ✅ Uploaded tweet 14531/14632
# ✅ Uploaded tweet 14532/14632
# ✅ Uploaded tweet 14533/14632
# ✅ Uploaded tweet 14534/14632
# ✅ Uploaded tweet 14535/14632
# ✅ Uploaded tweet 14536/14632
# ✅ Uploaded tweet 14537/14632
# ✅ Uploaded tweet 14538/14632
# ✅ Uploaded tweet 14539/14632
# ✅ Uploaded tweet 14540/14632
# ✅ Uploaded tweet 14541/14632
# ✅ Uploaded tweet 14542/14632
# ✅ Uploaded tweet 14543/14632
# ✅ Uploaded tweet 14544/14632
# ✅ Uploaded tweet 14545/14632
# ✅ Uploaded tweet 14546/14632
# ✅ Uploaded tweet 14547/14632
# ✅ Uploaded tweet 14548/14632
# ✅ Uploaded tweet 14549/14632
# ✅ Uploaded tweet 14550/14632
# ✅ Uploaded tweet 14551/14632
# ✅ Uploaded tweet 14552/14632
# ✅ Uploaded tweet 14553/14632
# ✅ Uploaded tweet 14554/14632
# ✅ Uploaded tweet 14555/14632
# ✅ Uploaded tweet 14556/14632
# ✅ Uploaded tweet 14557/14632
# ✅ Uploaded tweet 14558/14632
# ✅ Uploaded tweet 14559/14632
# ✅ Uploaded tweet 14560/14632
# ✅ Uploaded tweet 14561/14632
# ✅ Uploaded tweet 14562/14632
# ✅ Uploaded tweet 14563/14632
# ✅ Uploaded tweet 14564/14632
# ✅ Uploaded tweet 14565/14632
# ✅ Uploaded tweet 14566/14632
# ✅ Uploaded tweet 14567/14632
# ✅ Uploaded tweet 14568/14632
# ✅ Uploaded tweet 14569/14632
# ✅ Uploaded tweet 14570/14632
# ✅ Uploaded tweet 14571/14632
# ✅ Uploaded tweet 14572/14632
# ✅ Uploaded tweet 14573/14632
# ✅ Uploaded tweet 14574/14632
# ✅ Uploaded tweet 14575/14632
# ✅ Uploaded tweet 14576/14632
# ✅ Uploaded tweet 14577/14632
# ✅ Uploaded tweet 14578/14632
# ✅ Uploaded tweet 14579/14632
# ✅ Uploaded tweet 14580/14632
# ✅ Uploaded tweet 14581/14632
# ✅ Uploaded tweet 14582/14632
# ✅ Uploaded tweet 14583/14632
# ✅ Uploaded tweet 14584/14632
# ✅ Uploaded tweet 14585/14632
# ✅ Uploaded tweet 14586/14632
# ✅ Uploaded tweet 14587/14632
# ✅ Uploaded tweet 14588/14632
# ✅ Uploaded tweet 14589/14632
# ✅ Uploaded tweet 14590/14632
# ✅ Uploaded tweet 14591/14632
# ✅ Uploaded tweet 14592/14632
# ✅ Uploaded tweet 14593/14632
# ✅ Uploaded tweet 14594/14632
# ✅ Uploaded tweet 14595/14632
# ✅ Uploaded tweet 14596/14632
# ✅ Uploaded tweet 14597/14632
# ✅ Uploaded tweet 14598/14632
# ✅ Uploaded tweet 14599/14632
# ✅ Uploaded tweet 14600/14632
# ✅ Uploaded tweet 14601/14632
# ✅ Uploaded tweet 14602/14632
# ✅ Uploaded tweet 14603/14632
# ✅ Uploaded tweet 14604/14632
# ✅ Uploaded tweet 14605/14632
# ✅ Uploaded tweet 14606/14632
# ✅ Uploaded tweet 14607/14632
# ✅ Uploaded tweet 14608/14632
# ✅ Uploaded tweet 14609/14632
# ✅ Uploaded tweet 14610/14632
# ✅ Uploaded tweet 14611/14632
# ✅ Uploaded tweet 14612/14632
# ✅ Uploaded tweet 14613/14632
# ✅ Uploaded tweet 14614/14632
# ✅ Uploaded tweet 14615/14632
# ✅ Uploaded tweet 14616/14632
# ✅ Uploaded tweet 14617/14632
# ✅ Uploaded tweet 14618/14632
# ✅ Uploaded tweet 14619/14632
# ✅ Uploaded tweet 14620/14632
# ✅ Uploaded tweet 14621/14632
# ✅ Uploaded tweet 14622/14632
# ✅ Uploaded tweet 14623/14632
# ✅ Uploaded tweet 14624/14632
# ✅ Uploaded tweet 14625/14632
# ✅ Uploaded tweet 14626/14632
# ✅ Uploaded tweet 14627/14632
# ✅ Uploaded tweet 14628/14632
# ✅ Uploaded tweet 14629/14632
# ✅ Uploaded tweet 14630/14632
# ✅ Uploaded tweet 14631/14632
# ✅ Uploaded tweet 14632/14632

# %% [markdown]
# # 📈 Real-Time Sentiment Analysis Dashboard with Firebase and HuggingFace
# # This Dash web app displays real-time sentiment analysis of tweets using:
# 🔹 Firebase Firestore for data storage and retrieval.
# 🔹 HuggingFace Transformers for accurate sentiment classification.
# 🔹 PyDash and Plotly for interactive visualizations and UI.
# Features:
# ✅ Live refresh with sentiment filtering and dynamic chart selection (Pie/Bar).
# ✅ Search and analyze custom user-inputted tweets instantly.
# ✅ Secure, cloud-connected, and ready for real-time deployment.
# Designed for deployment in real-time analytics systems, especially for social media monitoring.

# %%
import dash
from dash import html, dcc, dash_table
import dash_bootstrap_components as dbc
import pandas as pd
import plotly.express as px
from firebase_admin import credentials, firestore, initialize_app
import firebase_admin
from dash.dependencies import Input, Output, State
from transformers import pipeline
import time

# ✅ Firebase Init
if not firebase_admin._apps:
    cred = credentials.Certificate("real-time-sentiment-anal-adf49-firebase-adminsdk-fbsvc-d2c025579f.json")
    initialize_app(cred)

db = firestore.client()

# ✅ HuggingFace Sentiment Pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

# ✅ Fetch Firestore Tweets
def fetch_data():
    tweets_ref = db.collection("tweet_sentiments").order_by("timestamp", direction=firestore.Query.DESCENDING).limit(500)
    docs = tweets_ref.stream()
    rows = [doc.to_dict() for doc in docs]
    return pd.DataFrame(rows)

# ✅ Classify New Tweet
def classify_tweet(text):
    result = sentiment_pipeline(text[:512])[0]
    return result["label"], float(result["score"])

# ✅ Dash App Setup
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])
app.title = "Tweet Sentiment Dashboard"

# ✅ Layout
app.layout = dbc.Container([
    html.H2("📊 Real-Time Tweet Sentiment Dashboard"),

    dbc.Row([
        dbc.Col(dcc.Dropdown(
            id='sentiment-filter',
            options=[{'label': s, 'value': s} for s in ['All', 'POSITIVE', 'NEGATIVE']],
            value='All',
            clearable=False
        ), md=4),

        dbc.Col(dcc.RadioItems(
            id='chart-type',
            options=[
                {'label': 'Pie Chart', 'value': 'pie'},
                {'label': 'Bar Chart', 'value': 'bar'}
            ],
            value='pie',
            inline=True
        ), md=4),

        dbc.Col(html.Div(id='last-refresh', style={'textAlign': 'right'}), md=4)
    ]),

    html.Br(),

    dcc.Interval(id="interval-refresh", interval=30 * 1000, n_intervals=0),

    dcc.Graph(id='sentiment-chart'),

    dash_table.DataTable(
        id='tweet-table',
        columns=[{"name": i, "id": i} for i in ['text', 'cleaned_text', 'sentiment', 'confidence']],
        style_table={'overflowX': 'auto'},
        style_cell={'textAlign': 'left'},
        page_size=10
    ),

    html.Hr(),

    html.H4("📝 Analyze Your Own Tweet"),
    dcc.Input(id='user-input', type='text', placeholder='Type your tweet here...', style={'width': '80%'}),
    html.Button('Analyze', id='analyze-btn', n_clicks=0),
    html.Div(id='prediction-output', style={'marginTop': '10px', 'fontWeight': 'bold', 'color': 'blue'})

], fluid=True)

# ✅ Callback: Main Table & Chart Refresh
@app.callback(
    [Output('tweet-table', 'data'),
     Output('sentiment-chart', 'figure'),
     Output('last-refresh', 'children')],
    [Input('sentiment-filter', 'value'),
     Input('chart-type', 'value'),
     Input('interval-refresh', 'n_intervals')]
)
def update_dashboard(selected_sentiment, chart_type, n):
    df = fetch_data()
    timestamp = f"Last updated: {time.strftime('%H:%M:%S')}"

    if df.empty:
        return [], {}, timestamp

    if selected_sentiment != 'All':
        df = df[df['sentiment'] == selected_sentiment]

    sentiment_counts = df['sentiment'].value_counts().reset_index()
    sentiment_counts.columns = ['sentiment', 'count']

    # Define custom colors
    color_map = {'POSITIVE': 'green', 'NEGATIVE': 'red', 'NEUTRAL': 'gray'}

    if chart_type == 'pie':
        fig = px.pie(
            sentiment_counts,
            values='count',
            names='sentiment',
            title='Sentiment Distribution',
            color='sentiment',
            color_discrete_map=color_map
        )
    else:
        fig = px.bar(
            sentiment_counts,
            x='sentiment',
            y='count',
            title='Sentiment Distribution',
            color='sentiment',
            color_discrete_map=color_map
        )

    return df[['text', 'cleaned_text', 'sentiment', 'confidence']].to_dict('records'), fig, timestamp

# ✅ Callback: Analyze User Input
@app.callback(
    Output('prediction-output', 'children'),
    [Input('analyze-btn', 'n_clicks')],
    [State('user-input', 'value')]
)
def predict_sentiment(n_clicks, user_text):
    if n_clicks > 0 and user_text:
        label, score = classify_tweet(user_text)
        return f"Prediction: {label} ({score:.2%} confidence)"
    return ""

# ✅ Run App
if __name__ == '__main__':
    app.run(debug=False, port=8501)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0

# %% [markdown]
# # 📦 Installing Neo4j Driver to Connect to Aura from Python

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /usr/local/lib/python3.11/dist-packages (5.28.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.2)

# %% [markdown]
# # 🔄 Uploading Sentiment Analysis Results to Neo4j Aura
#
# This code block connects to Neo4j Aura using secure credentials, verifies the connection,
# and uploads tweets along with their sentiment and confidence scores as graph nodes and relationships.

# %%
from neo4j import GraphDatabase

# ✅ Step 1: Neo4j Aura Credentials
NEO4J_URI = "neo4j+s://2e83b9f5.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "l3VCuoEgZYELmkgkZXgw3u5wn36QjYa1Kk4CG6IDOY0"  # ← REPLACE THIS with your real password from the "Reset Password" button

# ✅ Step 2: Create Driver and Verify Connection
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
driver.verify_connectivity()
print("✅ Connected to Neo4j Aura!")

# ✅ Step 3: Function to Upload Tweets to Neo4j
def upload_to_neo4j(df):
    with driver.session() as session:
        for i, row in df.iterrows():
            session.run("""
                MERGE (t:Tweet {text: $text})
                SET t.cleaned_text = $cleaned_text,
                    t.sentiment = $sentiment,
                    t.confidence = $confidence

                MERGE (s:Sentiment {type: $sentiment})
                MERGE (t)-[:HAS_SENTIMENT]->(s)
            """, {
                "text": row["text"],
                "cleaned_text": row["cleaned_text"],
                "sentiment": row["sentiment"],
                "confidence": float(row["confidence"])
            })
        print(f"✅ Uploaded {len(df)} tweets to Neo4j")

# ✅ Step 4: Run It
upload_to_neo4j(df_pandas)  # assuming df_pandas is your sentiment DataFrame
# Out:
# ✅ Connected to Neo4j Aura!
# ✅ Uploaded 14632 tweets to Neo4j

# %%
# !pip install dash dash-bootstrap-components neo4j pandas plotly
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: dash-bootstrap-components in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: neo4j in /usr/local/lib/python3.11/dist-packages (5.28.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.11/dist-packages (from dash) (3.0.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2025.4.26)

# %% [markdown]
# # 📊 Real-Time Tweet Sentiment Dashboard using Neo4j Aura and Dash
# This dashboard connects to Neo4j Aura to visualize sentiment analysis results from tweets.
# It supports:
# - 🔍 Live keyword-based tweet search
# - 📈 Sentiment type counts
# - 🌐 An interactive graph view of tweets and their associated sentiments
#
# Built with Python, Dash, Plotly, and Neo4j Aura.

# %%
import dash
from dash import dcc, html, Input, Output
import dash_bootstrap_components as dbc
from neo4j import GraphDatabase
import pandas as pd
import plotly.graph_objs as go
import networkx as nx

# ✅ Neo4j Aura connection
driver = GraphDatabase.driver(
    "neo4j+s://2e83b9f5.databases.neo4j.io",
    auth=("neo4j", "l3VCuoEgZYELmkgkZXgw3u5wn36QjYa1Kk4CG6IDOY0")
)

# ✅ Dash app setup
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    html.H2("Neo4j Tweet Sentiment Dashboard", className="text-center my-4"),

    dbc.Row([
        dbc.Col([
            html.Label("Search tweets by keyword:"),
            dcc.Input(id="keyword", type="text", value="", placeholder="e.g. happy", className="form-control"),
        ], width=6),
        dbc.Col([
            html.Label("Sentiment Count:"),
            html.Div(id="sentiment-counts", className="mt-2")
        ])
    ], className="mb-4"),

    dbc.Row([
        dbc.Col([
            html.H5("Matching Tweets"),
            html.Div(id="tweet-results", style={"maxHeight": "300px", "overflowY": "scroll"})
        ])
    ]),

    dbc.Row([
        dbc.Col([
            html.H5("Neo4j Graph View"),
            dcc.Graph(id="graph-view")
        ])
    ])
])

# ✅ Neo4j queries
def get_sentiment_counts():
    with driver.session() as session:
        result = session.run("""
            MATCH (:Tweet)-[:HAS_SENTIMENT]->(s:Sentiment)
            RETURN s.type AS sentiment, COUNT(*) AS count
        """)
        return pd.DataFrame([dict(r) for r in result])

def search_tweets(keyword):
    with driver.session() as session:
        result = session.run("""
            MATCH (t:Tweet)-[:HAS_SENTIMENT]->(s:Sentiment)
            WHERE toLower(t.cleaned_text) CONTAINS toLower($kw)
            RETURN t.text AS text, t.cleaned_text AS cleaned, t.sentiment AS sentiment, t.confidence AS confidence
            LIMIT 50
        """, {"kw": keyword})
        return pd.DataFrame([dict(r) for r in result])

def fetch_graph_data():
    with driver.session() as session:
        result = session.run("""
            MATCH (t:Tweet)-[:HAS_SENTIMENT]->(s:Sentiment)
            RETURN t.text AS tweet, s.type AS sentiment
            LIMIT 100
        """)
        return pd.DataFrame([dict(r) for r in result])

# ✅ Build plotly graph
def build_graph(df):
    nodes = []
    edges = []
    seen = set()

    for sentiment in df['sentiment'].unique():
        nodes.append(dict(id=sentiment, label=sentiment, color='blue'))
        seen.add(sentiment)

    for _, row in df.iterrows():
        tweet = row["tweet"]
        sentiment = row["sentiment"]
        if tweet not in seen:
            nodes.append(dict(id=tweet, label=tweet[:40] + "...", color='purple'))
            seen.add(tweet)
        edges.append((tweet, sentiment))

    G = nx.Graph()
    for n in nodes:
        G.add_node(n["id"], label=n["label"], color=n["color"])
    for s, t in edges:
        G.add_edge(s, t)

    pos = nx.spring_layout(G, k=0.5, iterations=50)

    edge_x, edge_y = [], []
    for s, t in G.edges():
        x0, y0 = pos[s]
        x1, y1 = pos[t]
        edge_x += [x0, x1, None]
        edge_y += [y0, y1, None]

    node_x, node_y, node_text, node_color = [], [], [], []
    for node, data in G.nodes(data=True):
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(data['label'])
        node_color.append(data['color'])

    edge_trace = go.Scatter(
        x=edge_x, y=edge_y, line=dict(width=1, color='#888'),
        hoverinfo='none', mode='lines'
    )

    node_trace = go.Scatter(
        x=node_x, y=node_y, mode='markers+text', text=node_text,
        textposition='top center',
        hoverinfo='text',
        marker=dict(color=node_color, size=10, line_width=2)
    )

    return go.Figure(data=[edge_trace, node_trace],
                     layout=go.Layout(
                         showlegend=False,
                         margin=dict(l=10, r=10, t=10, b=10),
                         hovermode='closest'
                     ))

# ✅ Callback
@app.callback(
    Output("sentiment-counts", "children"),
    Output("tweet-results", "children"),
    Output("graph-view", "figure"),
    Input("keyword", "value")
)
def update_dashboard(keyword):
    counts_df = get_sentiment_counts()
    tweets_df = search_tweets(keyword) if keyword else pd.DataFrame()
    graph_df = fetch_graph_data()

    count_list = html.Ul([html.Li(f"{row['sentiment']}: {row['count']}") for _, row in counts_df.iterrows()])
    tweet_list = html.Ul([
        html.Li([
            html.Strong(f"[{row['sentiment']}] "),
            html.Span(row['text']),
            html.Span(f" (conf: {row['confidence']:.2f})", style={"color": "gray", "fontSize": "0.9em"})
        ]) for _, row in tweets_df.iterrows()
    ]) if not tweets_df.empty else "No results."

    return count_list, tweet_list, build_graph(graph_df)

# ✅ Run server (correct version for Dash 2.0+)
if __name__ == "__main__":
    app.run(debug=True)
